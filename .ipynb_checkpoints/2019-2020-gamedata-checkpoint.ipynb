# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import numpy.ma as ma
from scipy.stats import linregress
import json as json
from ohmysportsfeedspy import MySportsFeeds
#from sports_api_key import api_key 
api_key = "2bfd18a3-290c-46de-a6a9-33b5ea"
msf = MySportsFeeds(version="2.0")
msf.authenticate(api_key, 'MYSPORTSFEEDS')

# %%
#output = msf.msf_get_data(league='nba',season='2018-2019-regular',feed='seasonal_games',format='json')
#print(output)

team_stats = ['teamStatsTotals']
team_data = []
stats_data = []

lastUpdate = ['lastUpdatedOn']
games = ['games']
#chedule = ['schedule']
for team in team_stats:
    response = msf.msf_get_data(league='nba',season='2019-2020-regular',feed='seasonal_games',format='json')
    lastUpdate.append(response['lastUpdatedOn'])
    games.append(response['games'])
    #chedule.append(response['schedule'])
#print(response)

# %%
nbaDict = games[1]
nbaData = pd.DataFrame(nbaDict)
nbaData
# Out:
#                                                schedule  \
# 0     {'id': 53038, 'startTime': '2019-10-23T00:00:0...
# 1     {'id': 53040, 'startTime': '2019-10-23T02:30:0...
# 2     {'id': 53041, 'startTime': '2019-10-23T23:00:0...
# 3     {'id': 53050, 'startTime': '2019-10-23T23:00:0...
# 4     {'id': 53051, 'startTime': '2019-10-23T23:00:0...
# ...                                                 ...
# 1225  {'id': 54259, 'startTime': '2020-04-15T23:30:0...
# 1226  {'id': 53039, 'startTime': '2020-04-15T23:30:0...
# 1227  {'id': 54258, 'startTime': '2020-04-16T02:00:0...
# 1228  {'id': 54257, 'startTime': '2020-04-16T02:00:0...
# 1229  {'id': 54256, 'startTime': '2020-04-16T02:00:0...
#
#                                                   score
# 0     {'currentQuarter': None, 'currentQuarterSecond...
# 1     {'currentQuarter': None, 'currentQuarterSecond...
# 2     {'currentQuarter': None, 'currentQuarterSecond...
# 3     {'currentQuarter': None, 'currentQuarterSecond...
# 4     {'currentQuarter': None, 'currentQuarterSecond...
# ...                                                 ...
# 1225  {'currentQuarter': None, 'currentQuarterSecond...
# 1226  {'currentQuarter': None, 'currentQuarterSecond...
# 1227  {'currentQuarter': None, 'currentQuarterSecond...
# 1228  {'currentQuarter': None, 'currentQuarterSecond...
# 1229  {'currentQuarter': None, 'currentQuarterSecond...
#
# [1230 rows x 2 columns]

# %%
nbaDataSchedule = pd.concat([nbaData.schedule.apply(pd.Series)], axis=1)

# %%
nbaDataSchedule.head()
# Out:
#       id                 startTime endedTime  \
# 0  53038  2019-10-23T00:00:00.000Z      None
# 1  53040  2019-10-23T02:30:00.000Z      None
# 2  53041  2019-10-23T23:00:00.000Z      None
# 3  53050  2019-10-23T23:00:00.000Z      None
# 4  53051  2019-10-23T23:00:00.000Z      None
#
#                              awayTeam                            homeTeam  \
# 0  {'id': 110, 'abbreviation': 'NOP'}   {'id': 81, 'abbreviation': 'TOR'}
# 1  {'id': 105, 'abbreviation': 'LAL'}  {'id': 102, 'abbreviation': 'LAC'}
# 2   {'id': 89, 'abbreviation': 'CHI'}   {'id': 93, 'abbreviation': 'CHA'}
# 3   {'id': 86, 'abbreviation': 'CLE'}   {'id': 95, 'abbreviation': 'ORL'}
# 4   {'id': 88, 'abbreviation': 'DET'}   {'id': 87, 'abbreviation': 'IND'}
#
#                                            venue venueAllegiance  \
# 0          {'id': 1, 'name': 'Scotiabank Arena'}            HOME
# 1           {'id': 25, 'name': 'Staples Center'}            HOME
# 2          {'id': 87, 'name': 'Spectrum Center'}            HOME
# 3             {'id': 89, 'name': 'Amway Center'}            HOME
# 4  {'id': 81, 'name': 'Bankers Life Fieldhouse'}            HOME
#
#   scheduleStatus originalStartTime delayedOrPostponedReason playedStatus  \
# 0         NORMAL              None                     None    COMPLETED
# 1         NORMAL              None                     None    COMPLETED
# 2         NORMAL              None                     None    COMPLETED
# 3         NORMAL              None                     None    COMPLETED
# 4         NORMAL              None                     None    COMPLETED
#
#   attendance officials broadcasters weather
# 0       None        []           []    None
# 1       None        []           []    None
# 2       None        []           []    None
# 3       None        []           []    None
# 4       None        []           []    None

# %%
nbaDataScore = pd.concat([nbaData.score.apply(pd.Series)], axis=1)
nbaDataScore.head()
# Out:
#   currentQuarter currentQuarterSecondsRemaining currentIntermission  \
# 0           None                           None                None
# 1           None                           None                None
# 2           None                           None                None
# 3           None                           None                None
# 4           None                           None                None
#
#    awayScoreTotal  homeScoreTotal  \
# 0           122.0           130.0
# 1           102.0           112.0
# 2           125.0           126.0
# 3            85.0            94.0
# 4           119.0           110.0
#
#                                             quarters
# 0  [{'quarterNumber': 1, 'awayScore': 30, 'homeSc...
# 1  [{'quarterNumber': 1, 'awayScore': 25, 'homeSc...
# 2  [{'quarterNumber': 1, 'awayScore': 28, 'homeSc...
# 3  [{'quarterNumber': 1, 'awayScore': 24, 'homeSc...
# 4  [{'quarterNumber': 1, 'awayScore': 27, 'homeSc...

# %%
nbaData_road = pd.concat([nbaDataSchedule.awayTeam.apply(pd.Series)], axis=1)
nbaData_road.head(10)
# Out:
#     id abbreviation
# 0  110          NOP
# 1  105          LAL
# 2   89          CHI
# 3   86          CLE
# 4   88          DET
# 5   82          BOS
# 6  107          MEM
# 7  100          MIN
# 8   83          NYK
# 9   94          WAS

# %%
nbaData_home = pd.concat([nbaDataSchedule.homeTeam.apply(pd.Series)], axis=1)
nbaData_home.head(10)
# Out:
#     id abbreviation
# 0   81          TOR
# 1  102          LAC
# 2   93          CHA
# 3   95          ORL
# 4   87          IND
# 5   85          PHI
# 6   92          MIA
# 7   84          BRO
# 8  106          SAS
# 9  108          DAL

# %%
nbaData_venue = pd.concat([nbaDataSchedule.venue.apply(pd.Series)], axis=1)
nbaData_venue.head(10)
# Out:
#    id                      name
# 0   1          Scotiabank Arena
# 1  25            Staples Center
# 2  87           Spectrum Center
# 3  89              Amway Center
# 4  81   Bankers Life Fieldhouse
# 5  29        Wells Fargo Center
# 6  86   American Airlines Arena
# 7  78           Barclays Center
# 8  99               AT&T Center
# 9   2  American Airlines Center

# %%
nbaRoadAbr = nbaData_road['abbreviation']
nbaHomeAbr = nbaData_home['abbreviation']
nbaVen = nbaData_venue['name']
nbascoresRoad = nbaDataScore['awayScoreTotal']
nbascoresHome = nbaDataScore['homeScoreTotal']
nbaDate = nbaDataSchedule['startTime']


filteredNBAdata = pd.DataFrame({"Date":nbaDate,
                                "Home Team":nbaHomeAbr,
                                "- Score":nbascoresHome,
                                "Road Team":nbaRoadAbr,
                                " - Score":nbascoresRoad,
                                "Venue":nbaVen,})

# %%
filteredNBAdata.to_csv('output_data/2019-2020-NBA.csv')
filteredNBAdata.head()
# Out:
#                        Date Home Team  - Score Road Team   - Score  \
# 0  2019-10-23T00:00:00.000Z       TOR    130.0       NOP     122.0
# 1  2019-10-23T02:30:00.000Z       LAC    112.0       LAL     102.0
# 2  2019-10-23T23:00:00.000Z       CHA    126.0       CHI     125.0
# 3  2019-10-23T23:00:00.000Z       ORL     94.0       CLE      85.0
# 4  2019-10-23T23:00:00.000Z       IND    110.0       DET     119.0
#
#                      Venue
# 0         Scotiabank Arena
# 1           Staples Center
# 2          Spectrum Center
# 3             Amway Center
# 4  Bankers Life Fieldhouse

# %%
#team_stats = ['teamStatsTotals']
team_data = []
stats_data = []

lastUpdate = ['lastUpdatedOn']
references = ['references']
#chedule = ['schedule']
for team in team_stats:
    response = msf.msf_get_data(league='nba',season='2019-2020-regular',feed='seasonal_games',format='json')
    lastUpdate.append(response['lastUpdatedOn'])
    references.append(response['references'])
    #chedule.append(response['schedule'])
#print(response)

# %%
#references

# %%
nbaRefDict = references[1]
nbaRefData = pd.DataFrame.from_dict(nbaRefDict, orient='index')
nbaRefData
# Out:
#                                                                 0   \
# teamReferences   {'id': 81, 'city': 'Toronto', 'name': 'Raptors...
# venueReferences  {'id': 1, 'name': 'Scotiabank Arena', 'city': ...
#
#                                                                 1   \
# teamReferences   {'id': 82, 'city': 'Boston', 'name': 'Celtics'...
# venueReferences  {'id': 2, 'name': 'American Airlines Center', ...
#
#                                                                 2   \
# teamReferences   {'id': 83, 'city': 'New York', 'name': 'Knicks...
# venueReferences  {'id': 12, 'name': 'Madison Square Garden', 'c...
#
#                                                                 3   \
# teamReferences   {'id': 84, 'city': 'Brooklyn', 'name': 'Nets',...
# venueReferences  {'id': 13, 'name': 'Capital One Arena', 'city'...
#
#                                                                 4   \
# teamReferences   {'id': 85, 'city': 'Philadelphia', 'name': '76...
# venueReferences  {'id': 19, 'name': 'Pepsi Center', 'city': 'De...
#
#                                                                 5   \
# teamReferences   {'id': 86, 'city': 'Cleveland', 'name': 'Caval...
# venueReferences  {'id': 20, 'name': 'State Farm Arena', 'city':...
#
#                                                                 6   \
# teamReferences   {'id': 87, 'city': 'Indiana', 'name': 'Pacers'...
# venueReferences  {'id': 25, 'name': 'Staples Center', 'city': '...
#
#                                                                 7   \
# teamReferences   {'id': 88, 'city': 'Detroit', 'name': 'Pistons...
# venueReferences  {'id': 27, 'name': 'TD Garden', 'city': 'Bosto...
#
#                                                                 8   \
# teamReferences   {'id': 89, 'city': 'Chicago', 'name': 'Bulls',...
# venueReferences  {'id': 28, 'name': 'United Center', 'city': 'C...
#
#                                                                 9   ...  \
# teamReferences   {'id': 90, 'city': 'Milwaukee', 'name': 'Bucks...  ...
# venueReferences  {'id': 29, 'name': 'Wells Fargo Center', 'city...  ...
#
#                                                                 20  \
# teamReferences   {'id': 101, 'city': 'Golden State', 'name': 'W...
# venueReferences  {'id': 98, 'name': 'Talking Stick Resort Arena...
#
#                                                                 21  \
# teamReferences   {'id': 102, 'city': 'Los Angeles', 'name': 'Cl...
# venueReferences  {'id': 99, 'name': 'AT&T Center', 'city': 'San...
#
#                                                                 22  \
# teamReferences   {'id': 103, 'city': 'Sacramento', 'name': 'Kin...
# venueReferences  {'id': 100, 'name': 'FedEx Forum', 'city': 'Me...
#
#                                                                 23  \
# teamReferences   {'id': 104, 'city': 'Phoenix', 'name': 'Suns',...
# venueReferences  {'id': 102, 'name': 'Toyota Center', 'city': '...
#
#                                                                 24  \
# teamReferences   {'id': 105, 'city': 'Los Angeles', 'name': 'La...
# venueReferences  {'id': 103, 'name': 'Smoothie King Center', 'c...
#
#                                                                 25  \
# teamReferences   {'id': 106, 'city': 'San Antonio', 'name': 'Sp...
# venueReferences  {'id': 145, 'name': 'Little Caesars Arena', 'c...
#
#                                                                 26  \
# teamReferences   {'id': 107, 'city': 'Memphis', 'name': 'Grizzl...
# venueReferences  {'id': 150, 'name': 'Chase Center', 'city': 'S...
#
#                                                                 27  \
# teamReferences   {'id': 108, 'city': 'Dallas', 'name': 'Maveric...
# venueReferences  {'id': 151, 'name': 'Golden 1 Center', 'city':...
#
#                                                                 28  \
# teamReferences   {'id': 109, 'city': 'Houston', 'name': 'Rocket...
# venueReferences  {'id': 152, 'name': 'Fiserv Forum', 'city': 'M...
#
#                                                                 29
# teamReferences   {'id': 110, 'city': 'New Orleans', 'name': 'Pe...
# venueReferences  {'id': 158, 'name': 'AccorHotels Arena', 'city...
#
# [2 rows x 30 columns]

# %%
nbaRef = nbaRefData.transpose()
nbaRef.head()
# Out:
#                                       teamReferences  \
# 0  {'id': 81, 'city': 'Toronto', 'name': 'Raptors...
# 1  {'id': 82, 'city': 'Boston', 'name': 'Celtics'...
# 2  {'id': 83, 'city': 'New York', 'name': 'Knicks...
# 3  {'id': 84, 'city': 'Brooklyn', 'name': 'Nets',...
# 4  {'id': 85, 'city': 'Philadelphia', 'name': '76...
#
#                                      venueReferences
# 0  {'id': 1, 'name': 'Scotiabank Arena', 'city': ...
# 1  {'id': 2, 'name': 'American Airlines Center', ...
# 2  {'id': 12, 'name': 'Madison Square Garden', 'c...
# 3  {'id': 13, 'name': 'Capital One Arena', 'city'...
# 4  {'id': 19, 'name': 'Pepsi Center', 'city': 'De...

# %%
nbaTeamRef = pd.concat([nbaRef.teamReferences.apply(pd.Series)], axis=1)
nbaTeamRef.head()
# Out:
#    id          city     name abbreviation  \
# 0  81       Toronto  Raptors          TOR
# 1  82        Boston  Celtics          BOS
# 2  83      New York   Knicks          NYK
# 3  84      Brooklyn     Nets          BRO
# 4  85  Philadelphia    76ers          PHI
#
#                                      homeVenue  \
# 0        {'id': 1, 'name': 'Scotiabank Arena'}
# 1              {'id': 27, 'name': 'TD Garden'}
# 2  {'id': 12, 'name': 'Madison Square Garden'}
# 3        {'id': 78, 'name': 'Barclays Center'}
# 4     {'id': 29, 'name': 'Wells Fargo Center'}
#
#                                   teamColoursHex  \
# 0           [#ce1141, #000000, #a1a1a4, #b4975a]
# 1  [#007a33, #ba9653, #963821, #e59e6d, #000000]
# 2           [#006bb6, #f58426, #bec0c2, #000000]
# 3                             [#000000, #ffffff]
# 4           [#006bb6, #ed174c, #002b5c, #c4ced4]
#
#                                  socialMediaAccounts  \
# 0     [{'mediaType': 'TWITTER', 'value': 'Raptors'}]
# 1     [{'mediaType': 'TWITTER', 'value': 'celtics'}]
# 2    [{'mediaType': 'TWITTER', 'value': 'nyknicks'}]
# 3  [{'mediaType': 'TWITTER', 'value': 'BrooklynNe...
# 4      [{'mediaType': 'TWITTER', 'value': 'sixers'}]
#
#                                 officialLogoImageSrc
# 0  https://global.nba.com/media/img/teams/00/logo...
# 1  https://global.nba.com/media/img/teams/00/logo...
# 2  https://global.nba.com/media/img/teams/00/logo...
# 3  https://global.nba.com/media/img/teams/00/logo...
# 4  https://global.nba.com/media/img/teams/00/logo...

# %%
nbaVenRef = pd.concat([nbaRef.venueReferences.apply(pd.Series)], axis=1)
nbaVenRef.head()
# Out:
#    id                      name            city country  \
# 0   1          Scotiabank Arena     Toronto, ON  Canada
# 1   2  American Airlines Center      Dallas, TX     USA
# 2  12     Madison Square Garden    New York, NY     USA
# 3  13         Capital One Arena  Washington, DC     USA
# 4  19              Pepsi Center      Denver, CO     USA
#
#                                      geoCoordinates  \
# 0  {'latitude': 43.643333, 'longitude': -79.379167}
# 1  {'latitude': 32.790556, 'longitude': -96.810278}
# 2  {'latitude': 40.750556, 'longitude': -73.993611}
# 3  {'latitude': 38.89801, 'longitude': -77.0231909}
# 4   {'latitude': 39.748611, 'longitude': -105.0075}
#
#                                capacitiesByEventType playingSurface  \
# 0  [{'eventType': 'ICE_HOCKEY', 'capacity': 20270...           None
# 1  [{'eventType': 'ICE_HOCKEY', 'capacity': 19323...       Multiple
# 2  [{'eventType': 'ICE_HOCKEY', 'capacity': 18006...           None
# 3  [{'eventType': 'ICE_HOCKEY', 'capacity': 18506...       Multiple
# 4  [{'eventType': 'ICE_HOCKEY', 'capacity': 17809...       Multiple
#
#   baseballDimensions  hasRoof  hasRetractableRoof
# 0                 []     True               False
# 1                 []     True               False
# 2                 []     True               False
# 3                 []     True               False
# 4                 []     True               False

# %%
nbaGeoRef = pd.concat([nbaVenRef.geoCoordinates.apply(pd.Series)], axis=1)
nbaGeoRef.head()
# Out:
#     latitude   longitude
# 0  43.643333  -79.379167
# 1  32.790556  -96.810278
# 2  40.750556  -73.993611
# 3  38.898010  -77.023191
# 4  39.748611 -105.007500

# %%
teamName = nbaTeamRef['name']
teamAbr = nbaTeamRef['abbreviation']
teamCity = nbaVenRef['city']
teamArena = nbaVenRef['name']
teamLat = nbaGeoRef['latitude']
teamLng = nbaGeoRef['longitude']

filteredNBAref = pd.DataFrame({"Team Name":teamName,
                                "Abbreviation":teamAbr,
                                "City, State": teamCity,
                                "Venue":teamArena,
                                "Latitude":teamLat,
                               "Longitude":teamLng})

# %%
filteredNBAref.to_csv('output_data/NBA_venua.csv')
filteredNBAref
# Out:
#         Team Name Abbreviation         City, State  \
# 0         Raptors          TOR         Toronto, ON
# 1         Celtics          BOS          Dallas, TX
# 2          Knicks          NYK        New York, NY
# 3            Nets          BRO      Washington, DC
# 4           76ers          PHI          Denver, CO
# 5       Cavaliers          CLE         Atlanta, GA
# 6          Pacers          IND     Los Angeles, CA
# 7         Pistons          DET          Boston, MA
# 8           Bulls          CHI         Chicago, IL
# 9           Bucks          MIL    Philadelphia, PA
# 10          Hawks          ATL        Brooklyn, NY
# 11           Heat          MIA       Cleveland, OH
# 12        Hornets          CHA    Indianapolis, IN
# 13        Wizards          WAS           Miami, FL
# 14          Magic          ORL       Charlotte, NC
# 15        Thunder          OKL         Orlando, FL
# 16  Trail Blazers          POR   Oklahama City, OK
# 17           Jazz          UTA        Portland, OR
# 18        Nuggets          DEN  Salt Lake City, UT
# 19   Timberwolves          MIN     Minneapolis, MN
# 20       Warriors          GSW         Phoenix, AZ
# 21       Clippers          LAC     San Antonio, TX
# 22          Kings          SAC         Memphis, TN
# 23           Suns          PHX         Houston, TX
# 24         Lakers          LAL     New Orleans, LA
# 25          Spurs          SAS         Detroit, MI
# 26      Grizzlies          MEM   San Francisco, CA
# 27      Mavericks          DAL      Sacramento, CA
# 28        Rockets          HOU       Milwaukee, WI
# 29       Pelicans          NOP               Paris
#
#                          Venue   Latitude   Longitude
# 0             Scotiabank Arena  43.643333  -79.379167
# 1     American Airlines Center  32.790556  -96.810278
# 2        Madison Square Garden  40.750556  -73.993611
# 3            Capital One Arena  38.898010  -77.023191
# 4                 Pepsi Center  39.748611 -105.007500
# 5             State Farm Arena  33.757222  -84.396389
# 6               Staples Center  34.043056 -118.267222
# 7                    TD Garden  42.366303  -71.062228
# 8                United Center  41.880556  -87.674167
# 9           Wells Fargo Center  39.901111  -75.171944
# 10             Barclays Center  40.682661  -73.975225
# 11         Quicken Loans Arena  41.496389  -81.688056
# 12     Bankers Life Fieldhouse  39.763889  -86.155556
# 13     American Airlines Arena  25.781389  -80.188056
# 14             Spectrum Center  35.225000  -80.839167
# 15                Amway Center  28.539167  -81.383611
# 16     Chesapeake Energy Arena  35.463333  -97.515000
# 17                 Moda Center  45.531667 -122.666667
# 18     Vivint Smart Home Arena  40.768333 -111.901111
# 19               Target Center  44.979444  -93.276111
# 20  Talking Stick Resort Arena  33.445833 -112.071389
# 21                 AT&T Center  29.426944  -98.437500
# 22                 FedEx Forum  35.138333  -90.050556
# 23               Toyota Center  29.750833  -95.362222
# 24        Smoothie King Center  29.948889  -90.081944
# 25        Little Caesars Arena  42.341111  -83.055000
# 26                Chase Center  37.768056 -122.387500
# 27             Golden 1 Center  38.580361 -121.499611
# 28                Fiserv Forum  43.045028  -87.918167
# 29           AccorHotels Arena  48.838653    2.378500
