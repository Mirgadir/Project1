# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import numpy.ma as ma
from scipy.stats import linregress
import json as json
from ohmysportsfeedspy import MySportsFeeds
#from sports_api_key import api_key 
#api_key = 
output_data_file = "output_data/nba.csv"

msf = MySportsFeeds(version="2.0")
msf.authenticate(api_key, 'MYSPORTSFEEDS')

# %%
#output = msf.msf_get_data(league='nba',season='2018-2019-regular',feed='seasonal_games1',format='json')
#print(output)

team_stats = ['teamStatsTotals']
team_data = []
stats_data = []

lastUpdate = ['lastUpdatedOn']
#games = ['games']
#chedule = ['schedule']
for team in team_stats:
    response = msf.msf_get_data(league='nba',season='2019-2020-regular',feed='seasonal_team_stats',format='json')
    lastUpdate.append(response['lastUpdatedOn'])
    stats_data.append(response['teamStatsTotals'])
    #chedule.append(response['schedule'])
#print(response)

# %%
nbaStatsDict = stats_data
nbaStatsData = pd.DataFrame(stats_data)
nbaStatsData
# Out:
#                                                   0   \
# 0  {'team': {'id': 91, 'city': 'Atlanta', 'name':...
#
#                                                   1   \
# 0  {'team': {'id': 82, 'city': 'Boston', 'name': ...
#
#                                                   2   \
# 0  {'team': {'id': 84, 'city': 'Brooklyn', 'name'...
#
#                                                   3   \
# 0  {'team': {'id': 93, 'city': 'Charlotte', 'name...
#
#                                                   4   \
# 0  {'team': {'id': 89, 'city': 'Chicago', 'name':...
#
#                                                   5   \
# 0  {'team': {'id': 86, 'city': 'Cleveland', 'name...
#
#                                                   6   \
# 0  {'team': {'id': 108, 'city': 'Dallas', 'name':...
#
#                                                   7   \
# 0  {'team': {'id': 99, 'city': 'Denver', 'name': ...
#
#                                                   8   \
# 0  {'team': {'id': 88, 'city': 'Detroit', 'name':...
#
#                                                   9   ...  \
# 0  {'team': {'id': 101, 'city': 'Golden State', '...  ...
#
#                                                   20  \
# 0  {'team': {'id': 96, 'city': 'Oklahoma City', '...
#
#                                                   21  \
# 0  {'team': {'id': 95, 'city': 'Orlando', 'name':...
#
#                                                   22  \
# 0  {'team': {'id': 85, 'city': 'Philadelphia', 'n...
#
#                                                   23  \
# 0  {'team': {'id': 104, 'city': 'Phoenix', 'name'...
#
#                                                   24  \
# 0  {'team': {'id': 97, 'city': 'Portland', 'name'...
#
#                                                   25  \
# 0  {'team': {'id': 103, 'city': 'Sacramento', 'na...
#
#                                                   26  \
# 0  {'team': {'id': 106, 'city': 'San Antonio', 'n...
#
#                                                   27  \
# 0  {'team': {'id': 81, 'city': 'Toronto', 'name':...
#
#                                                   28  \
# 0  {'team': {'id': 98, 'city': 'Utah', 'name': 'J...
#
#                                                   29
# 0  {'team': {'id': 94, 'city': 'Washington', 'nam...
#
# [1 rows x 30 columns]

# %%
nbaStats = nbaStatsData.transpose()

# %%
nbaStats.rename(columns = {0:'Data'}, inplace = True) 
nbaStatsConc = pd.concat([nbaStats.Data.apply(pd.Series)], axis=1)
nbaStatsConc.head()
# Out:
#                                                 team  \
# 0  {'id': 91, 'city': 'Atlanta', 'name': 'Hawks',...
# 1  {'id': 82, 'city': 'Boston', 'name': 'Celtics'...
# 2  {'id': 84, 'city': 'Brooklyn', 'name': 'Nets',...
# 3  {'id': 93, 'city': 'Charlotte', 'name': 'Horne...
# 4  {'id': 89, 'city': 'Chicago', 'name': 'Bulls',...
#
#                                                stats
# 0  {'gamesPlayed': 67, 'fieldGoals': {'fg2PtAtt':...
# 1  {'gamesPlayed': 64, 'fieldGoals': {'fg2PtAtt':...
# 2  {'gamesPlayed': 64, 'fieldGoals': {'fg2PtAtt':...
# 3  {'gamesPlayed': 65, 'fieldGoals': {'fg2PtAtt':...
# 4  {'gamesPlayed': 65, 'fieldGoals': {'fg2PtAtt':...

# %%
statTeamData = pd.concat([nbaStatsConc.team.apply(pd.Series)], axis=1)
statTeamData.head(1)
# Out:
#    id     city   name abbreviation                               homeVenue  \
# 0  91  Atlanta  Hawks          ATL  {'id': 20, 'name': 'State Farm Arena'}
#
#                 teamColoursHex  \
# 0  [#e03a3e, #c1d32f, #26282a]
#
#                                socialMediaAccounts  \
# 0  [{'mediaType': 'TWITTER', 'value': 'ATLHawks'}]
#
#                                 officialLogoImageSrc
# 0  https://global.nba.com/media/img/teams/00/logo...

# %%
nbaTeamStats = pd.concat([nbaStatsConc.stats.apply(pd.Series)], axis=1)
nbaTeamStats.head(1)
# Out:
#    gamesPlayed                                         fieldGoals  \
# 0           67  {'fg2PtAtt': 3653, 'fg2PtAttPerGame': 54.5, 'f...
#
#                                           freeThrows  \
# 0  {'ftAtt': 1566, 'ftAttPerGame': 23.4, 'ftMade'...
#
#                                             rebounds  \
# 0  {'offReb': 662, 'offRebPerGame': 9.9, 'defReb'...
#
#                                              offense  \
# 0  {'ast': 1605, 'astPerGame': 24.0, 'pts': 7488,...
#
#                                              defense  \
# 0  {'tov': 1054, 'tovPerGame': 15.7, 'stl': 523, ...
#
#                                        miscellaneous  \
# 0  {'fouls': 1597, 'foulsPerGame': 23.8, 'foulsDr...
#
#                                            standings
# 0  {'wins': 20, 'losses': 47, 'winPct': 0.299, 'g...

# %%
nbaStatsFG = pd.concat([nbaTeamStats.fieldGoals.apply(pd.Series)], axis=1)
nbaStatsFG.head(1)
# Out:
#    fg2PtAtt  fg2PtAttPerGame  fg2PtMade  fg2PtMadePerGame  fg2PtPct  fg3PtAtt  \
# 0    3653.0             54.5     1919.0              28.6      52.5    2416.0
#
#    fg3PtAttPerGame  fg3PtMade  fg3PtMadePerGame  fg3PtPct   fgAtt  \
# 0             36.1      805.0              12.0      33.3  6068.0
#
#    fgAttPerGame  fgMade  fgMadePerGame  fgPct
# 0          90.6  2723.0           40.6   44.9

# %%
nbaStatsOFF = pd.concat([nbaTeamStats.offense.apply(pd.Series)], axis=1)
nbaStatsOFF.head(1)
# Out:
#       ast  astPerGame     pts  ptsPerGame
# 0  1605.0        24.0  7488.0       111.8

# %%
nbaStatsDEF = pd.concat([nbaTeamStats.defense.apply(pd.Series)], axis=1)
nbaStatsDEF.head(1)
# Out:
#       tov  tovPerGame    stl  stlPerGame    blk  blkPerGame  blkAgainst  \
# 0  1054.0        15.7  523.0         7.8  341.0         5.1       429.0
#
#    blkAgainstPerGame  ptsAgainst  ptsAgainstPerGame
# 0                6.4      8027.0              119.8

# %%
nbaStatsMISC = pd.concat([nbaTeamStats.miscellaneous.apply(pd.Series)], axis=1)
nbaStatsMISC.head(1)
# Out:
#     fouls  foulsPerGame  foulsDrawn  foulsDrawnPerGame  foulPers  \
# 0  1597.0          23.8      1406.0               21.0    1548.0
#
#    foulPersPerGame  foulPersDrawn  foulPersDrawnPerGame  foulTech  \
# 0             23.1         1399.0                  20.9    1548.0
#
#    foulTechPerGame  ...  foulFlag1PerGame  foulFlag1Drawn  \
# 0              0.4  ...               0.0             4.0
#
#    foulFlag1DrawnPerGame  foulFlag2  foulFlag2PerGame  foulFlag2Drawn  \
# 0                    0.1        0.0               0.0             1.0
#
#    foulFlag2DrawnPerGame  ejections  plusMinus  plusMinusPerGame
# 0                    0.0        1.0     -539.0              -8.0
#
# [1 rows x 23 columns]

# %%
nbaStatsSTAND = pd.concat([nbaTeamStats.standings.apply(pd.Series)], axis=1)
nbaStatsSTAND.head(1)
# Out:
#    wins  losses  winPct  gamesBack
# 0  20.0    47.0   0.299        0.0

# %%
teamAbr = statTeamData['abbreviation']
teamName = statTeamData['name']
pt2FGpct = nbaStatsFG['fg2PtPct']
pt3FGpct = nbaStatsFG['fg3PtPct']
totFGpct = nbaStatsFG['fgPct']
ptsScored = nbaStatsOFF['ptsPerGame']
tovPerGam = nbaStatsDEF['tovPerGame']
PtsAgainst = nbaStatsDEF['ptsAgainstPerGame']
teamWins = nbaStatsSTAND['wins']
teamLoss = nbaStatsSTAND['losses']
teamWinPct = nbaStatsSTAND['winPct']

pointDif = ptsScored - PtsAgainst



filtTeamStats = pd.DataFrame({"Abr":teamAbr,
                              "Team Name":teamName,
                              "Wins":teamWins,
                              "Losses":teamLoss,
                              "Win Pct":teamWinPct,
                              "FG % (2pt)":pt2FGpct,
                              "FG% (3pt)":pt3FGpct,
                              "Total FG%":totFGpct,
                              "Turnovers Committed":tovPerGam,
                              "Avg Points Scored":ptsScored,
                              "Avg Poinst Against":PtsAgainst,
                              "Avg Point Differentiation": pointDif
                              
})

# %%
filtTeamStats.to_csv('output_data/2019-20_TEAMSTATS.csv')
filtTeamStats
# Out:
#     Abr      Team Name  Wins  Losses  Win Pct  FG % (2pt)  FG% (3pt)  \
# 0   ATL          Hawks  20.0    47.0    0.299        52.5       33.3
# 1   BOS        Celtics  43.0    21.0    0.672        51.9       36.3
# 2   BRO           Nets  30.0    34.0    0.469        51.9       34.0
# 3   CHA        Hornets  23.0    42.0    0.354        48.9       35.2
# 4   CHI          Bulls  22.0    43.0    0.338        51.1       34.7
# 5   CLE      Cavaliers  19.0    46.0    0.292        51.9       35.1
# 6   DAL      Mavericks  40.0    27.0    0.597        54.3       36.9
# 7   DEN        Nuggets  43.0    22.0    0.662        52.9       35.8
# 8   DET        Pistons  20.0    46.0    0.303        51.5       36.7
# 9   GSW       Warriors  15.0    50.0    0.231        49.6       33.4
# 10  HOU        Rockets  40.0    24.0    0.625        55.4       34.8
# 11  IND         Pacers  39.0    26.0    0.600        52.8       36.3
# 12  LAC       Clippers  44.0    20.0    0.688        52.1       36.6
# 13  LAL         Lakers  49.0    14.0    0.778        55.6       35.5
# 14  MEM      Grizzlies  32.0    33.0    0.492        53.1       35.2
# 15  MIA           Heat  41.0    24.0    0.631        53.0       38.3
# 16  MIL          Bucks  53.0    12.0    0.815        56.6       35.6
# 17  MIN   Timberwolves  19.0    45.0    0.297        52.1       33.6
# 18  NOP       Pelicans  28.0    36.0    0.438        52.5       37.2
# 19  NYK         Knicks  21.0    45.0    0.318        49.9       33.7
# 20  OKL        Thunder  40.0    24.0    0.625        53.6       35.5
# 21  ORL          Magic  30.0    35.0    0.462        49.9       34.1
# 22  PHI          76ers  39.0    26.0    0.600        52.3       36.2
# 23  PHX           Suns  26.0    39.0    0.400        52.6       35.3
# 24  POR  Trail Blazers  29.0    37.0    0.439        51.3       37.2
# 25  SAC          Kings  28.0    36.0    0.438        52.1       36.4
# 26  SAS          Spurs  27.0    36.0    0.429        51.7       37.1
# 27  TOR        Raptors  46.0    18.0    0.719        52.1       37.1
# 28  UTA           Jazz  41.0    23.0    0.641        53.8       38.3
# 29  WAS        Wizards  24.0    40.0    0.375        51.1       37.2
#
#     Total FG%  Turnovers Committed  Avg Points Scored  Avg Poinst Against  \
# 0        44.9                 15.7              111.8               119.8
# 1        45.9                 13.0              113.0               106.7
# 2        44.4                 14.8              110.8               111.4
# 3        43.4                 13.9              102.9               109.6
# 4        44.6                 14.6              106.8               109.9
# 5        45.8                 15.7              106.9               114.7
# 6        46.2                 12.2              116.4               110.4
# 7        47.1                 12.9              110.4               107.4
# 8        45.9                 14.6              107.2               110.8
# 9        43.8                 14.3              106.3               115.0
# 10       45.4                 14.1              118.1               114.4
# 11       47.7                 12.5              109.3               107.4
# 12       46.4                 14.1              116.2               109.6
# 13       48.5                 14.5              114.3               106.9
# 14       47.0                 14.6              112.6               113.7
# 15       46.9                 13.9              112.2               108.9
# 16       47.7                 14.4              118.6               107.4
# 17       44.1                 14.7              113.2               117.5
# 18       46.2                 15.7              116.2               117.0
# 19       44.8                 13.9              105.8               112.3
# 20       47.3                 12.7              110.8               108.3
# 21       44.2                 12.0              106.4               107.2
# 22       46.5                 13.4              109.6               107.3
# 23       46.4                 14.5              112.6               113.9
# 24       46.1                 12.6              113.6               115.3
# 25       45.9                 13.7              109.0               110.9
# 26       47.0                 11.9              113.2               114.9
# 27       45.8                 13.6              113.0               106.5
# 28       47.5                 14.3              111.0               107.9
# 29       46.1                 13.4              115.6               119.7
#
#     Avg Point Differentiation
# 0                        -8.0
# 1                         6.3
# 2                        -0.6
# 3                        -6.7
# 4                        -3.1
# 5                        -7.8
# 6                         6.0
# 7                         3.0
# 8                        -3.6
# 9                        -8.7
# 10                        3.7
# 11                        1.9
# 12                        6.6
# 13                        7.4
# 14                       -1.1
# 15                        3.3
# 16                       11.2
# 17                       -4.3
# 18                       -0.8
# 19                       -6.5
# 20                        2.5
# 21                       -0.8
# 22                        2.3
# 23                       -1.3
# 24                       -1.7
# 25                       -1.9
# 26                       -1.7
# 27                        6.5
# 28                        3.1
# 29                       -4.1

# %%
plt.scatter(teamWinPct, pointDif, marker="o", facecolors="green")
#plt.ylim(33,47)
#plt.xlim(14,26)
plt.title("NBA Teams, Win Pct vs Point Diff")
plt.xlabel("Winning Percentage")
plt.ylabel("Point Diff")
plt.show()

# %%
#gkey = 
import gmaps
gmaps.configure(api_key=gkey)
teamGPSdata_csv = 'output_data/NBA_venua.csv'
teamGPSdata = pd.read_csv(teamGPSdata_csv)

dataForNBAmap = pd.merge(filtTeamStats, teamGPSdata, how='outer', on='Team Name')
dataForNBAmap.head()
# Out:
#    Abr Team Name  Wins  Losses  Win Pct  FG % (2pt)  FG% (3pt)  Total FG%  \
# 0  ATL     Hawks  20.0    47.0    0.299        52.5       33.3       44.9
# 1  BOS   Celtics  43.0    21.0    0.672        51.9       36.3       45.9
# 2  BRO      Nets  30.0    34.0    0.469        51.9       34.0       44.4
# 3  CHA   Hornets  23.0    42.0    0.354        48.9       35.2       43.4
# 4  CHI     Bulls  22.0    43.0    0.338        51.1       34.7       44.6
#
#    Turnovers Committed  Avg Points Scored  Avg Poinst Against  \
# 0                 15.7              111.8               119.8
# 1                 13.0              113.0               106.7
# 2                 14.8              110.8               111.4
# 3                 13.9              102.9               109.6
# 4                 14.6              106.8               109.9
#
#    Avg Point Differentiation  Unnamed: 0 Abbreviation    City, State  \
# 0                       -8.0           0          ATL    Atlanta, GA
# 1                        6.3           1          BOS     Boston, MA
# 2                       -0.6           2          BRO   Brooklyn, NY
# 3                       -6.7           3          CHA  Charlotte, NC
# 4                       -3.1           4          CHI    Chicago, IL
#
#               Venue   Latitude  Longitude
# 0  State Farm Arena  33.757222 -84.396389
# 1         TD Garden  42.366303 -71.062228
# 2   Barclays Center  40.682661 -73.975225
# 3   Spectrum Center  35.225000 -80.839167
# 4     United Center  41.880556 -87.674167

# %%
venueList = dataForNBAmap["Team Name"].tolist()

locations = dataForNBAmap[["Latitude", "Longitude"]]
scorePct = dataForNBAmap["Win Pct"].astype(float)
fig = gmaps.figure()
heat_layer = gmaps.heatmap_layer(locations, weights=scorePct, 
                                 dissipating=False, max_intensity=max(scorePct),
                                 point_radius=3)

info_box_template = """

<dl>
<dt>Name</dt><dd>{Team Name}</dd>
<dt>City</dt><dd>{City, State}</dd>
</dl>
"""



nbaCityinfo = [info_box_template.format(**row) for index, row in dataForNBAmap.iterrows()]
marker_locations = dataForNBAmap[["Latitude", "Longitude"]]

markers = gmaps.marker_layer(marker_locations,
    info_box_content=[f"Team: {list}" for list in venueList])

fig.add_layer(markers)
fig.add_layer(heat_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
