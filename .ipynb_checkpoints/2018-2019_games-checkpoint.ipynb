# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import numpy.ma as ma
from scipy.stats import linregress
import json as json
from ohmysportsfeedspy import MySportsFeeds
from sports_api_key import api_key 

msf = MySportsFeeds(version="2.0")
msf.authenticate(api_key, 'MYSPORTSFEEDS')

# %%
#output = msf.msf_get_data(league='nba',season='2018-2019-regular',feed='seasonal_games',format='json')
#print(output)

team_stats = ['teamStatsTotals']
team_data = []
stats_data = []

lastUpdate = ['lastUpdatedOn']
games = ['games']
#chedule = ['schedule']
for team in team_stats:
    response = msf.msf_get_data(league='nba',season='2018-2019-regular',feed='seasonal_games',format='json')
    lastUpdate.append(response['lastUpdatedOn'])
    games.append(response['games'])
    #chedule.append(response['schedule'])
print(response)
# Out:
# {'lastUpdatedOn': '2020-06-19T16:45:18.311Z', 'games': [{'schedule': {'id': 47570, 'startTime': '2018-10-17T00:00:00.000Z', 'endedTime': None, 'awayTeam': {'id': 85, 'abbreviation': 'PHI'}, 'homeTeam': {'id': 82, 'abbreviation': 'BOS'}, 'venue': {'id': 27, 'name': 'TD Garden'}, 'venueAllegiance': 'HOME', 'scheduleStatus': 'NORMAL', 'originalStartTime': None, 'delayedOrPostponedReason': None, 'playedStatus': 'COMPLETED', 'attendance': None, 'officials': [], 'broadcasters': [], 'weather': None}, 'score': {'currentQuarter': None, 'currentQuarterSecondsRemaining': None, 'currentIntermission': None, 'awayScoreTotal': 87, 'homeScoreTotal': 105, 'quarters': [{'quarterNumber': 1, 'awayScore': 21, 'homeScore': 21}, {'quarterNumber': 2, 'awayScore': 21, 'homeScore': 26}, {'quarterNumber': 3, 'awayScore': 24, 'homeScore': 30}, {'quarterNumber': 4, 'awayScore': 21, 'homeScore': 28}]}}, {'schedule': {'id': 47571, 'startTime': '2018-10-17T02:30:00.000Z', 'endedTime': None, 'awayTeam': {'id': 96, 'abbreviation': 'OKL'}, 'homeTeam': {'id': 101, 'abbreviation': 'GSW'}, 'venue': {'id': 95, 'name': 'Oracle Arena'}, 'venueAllegiance': 'HOME', 'scheduleStatus': 'NORMAL', 'originalStartTime': None, 'delayedOrPostponedReason': None, 'playedStatus': 'COMPLETED', 'attendance': None, 'officials': [], 'broadcasters': [], 'weather': None}, 'score': {'currentQuarter': None, 'currentQuarterSecondsRemaining': None, 'currentIntermission': None, 'awayScoreTotal': 100, 'homeScoreTotal': 108, 'quarters': [{'quarterNumber': 1, 'awayScore': 23, 'homeScore': 31}, {'quarterNumber': 2, 'awayScore': 24, 'homeScore': 26}, {'quarterNumber': 3, 'awayScore': 32, 'homeScore': 26}, {'quarterNumber': 4, 'awayScore': 21, 'homeScore': 25}]}}, {'schedule': {'id': 47572, 'startTime': '2018-10-17T23:00:00.000Z', 'endedTime': None, 'awayTeam': {'id': 90, 'abbreviation': 'MIL'}, 'homeTeam': {'id': 93, 'abbreviation': 'CHA'}, 'venue': {'id': 87, 'name': 'Spectrum Center'}, 'venueAllegiance': 'HOME', 'scheduleStatus': 'NORMAL', 'originalStartTime': None, 'delayedOrPostponedReason': None, 'playedStatus': 'COMPLETED', 'attendance': None, 'officials': [], 'broadcasters': [], 'weather': None}, 'score': {'currentQuarter': None, 'currentQuarterSecondsRemaining': None, 'currentIntermission': None, 'awayScoreTotal': 113, 'homeScoreTotal': 112, 'quarters': [{'quarterNumber': 1, 'awayScore': 36, 'homeScore': 23}, {'quarterNumber': 2, 'awayScore': 31, 'homeScore': 31}, {'quarterNumber': 3, 'awayScore': 26, 'homeScore': 29}, {'quarterNumber': 4, 'awayScore': 20, 'homeScore': 29}]}}, {'schedule': {'id': 47573, 'startTime': '2018-10-17T23:00:00.000Z', 'endedTime': None, 'awayTeam': {'id': 84, 'abbreviation': 'BRO'}, 'homeTeam': {'id': 88, 'abbreviation': 'DET'}, 'venue': {'id': 145, 'name': 'Little Caesars Arena'}, 'venueAllegiance': 'HOME', 'scheduleStatus': 'NORMAL', 'originalStartTime': None, 'delayedOrPostponedReason': None, 'playedStatus': 'COMPLETED', 'attendance': None, 'officials': [], 'broadcasters': [], 'weather': None}, 'score': {'currentQuarter': None, 'currentQuarterSecondsRemaining': None, 'currentIntermission': None, 'awayScoreTotal': 100, 'homeScoreTotal': 103, 'quarters': [{'quarterNumber': 1, 'awayScore': 29, 'homeScore': 24}, {'quarterNumber': 2, 'awayScore': 22, 'homeScore': 27}, {'quarterNumber': 3, 'awayScore': 25, 'homeScore': 32}, {'quarterNumber': 4, 'awayScore': 24, 'homeScore': 20}]}}, {'schedule': {'id': 47574, 'startTime': '2018-10-17T23:00:00.000Z', 'endedTime': None, 'awayTeam': {'id': 107, 'abbreviation': 'MEM'}, 'homeTeam': {'id': 87, 'abbreviation': 'IND'}, 'venue': {'id': 81, 'name': 'Bankers Life Fieldhouse'}, 'venueAllegiance': 'HOME', 'scheduleStatus': 'NORMAL', 'originalStartTime': None, 'delayedOrPostponedReason': None, 'playedStatus': 'COMPLETED', 'attendance': None, 'officials': [], 'broadcasters': [], 'weather': None}, 'score': {'currentQuarter': None, 'currentQuarterSecondsRemaining': None, 'currentIntermission': None, 'awayScoreTotal': 83, 'homeScoreTo ...

# %%
nbaDict = games[1]
nbaData = pd.DataFrame(nbaDict)
nbaData
# Out:
#                                                schedule  \
# 0     {'id': 47570, 'startTime': '2018-10-17T00:00:0...
# 1     {'id': 47571, 'startTime': '2018-10-17T02:30:0...
# 2     {'id': 47572, 'startTime': '2018-10-17T23:00:0...
# 3     {'id': 47573, 'startTime': '2018-10-17T23:00:0...
# 4     {'id': 47574, 'startTime': '2018-10-17T23:00:0...
# ...                                                 ...
# 1225  {'id': 48795, 'startTime': '2019-04-11T00:00:0...
# 1226  {'id': 48796, 'startTime': '2019-04-11T00:00:0...
# 1227  {'id': 48797, 'startTime': '2019-04-11T02:30:0...
# 1228  {'id': 48798, 'startTime': '2019-04-11T02:30:0...
# 1229  {'id': 48799, 'startTime': '2019-04-11T02:30:0...
#
#                                                   score
# 0     {'currentQuarter': None, 'currentQuarterSecond...
# 1     {'currentQuarter': None, 'currentQuarterSecond...
# 2     {'currentQuarter': None, 'currentQuarterSecond...
# 3     {'currentQuarter': None, 'currentQuarterSecond...
# 4     {'currentQuarter': None, 'currentQuarterSecond...
# ...                                                 ...
# 1225  {'currentQuarter': None, 'currentQuarterSecond...
# 1226  {'currentQuarter': None, 'currentQuarterSecond...
# 1227  {'currentQuarter': None, 'currentQuarterSecond...
# 1228  {'currentQuarter': None, 'currentQuarterSecond...
# 1229  {'currentQuarter': None, 'currentQuarterSecond...
#
# [1230 rows x 2 columns]

# %%
# Out:
# [{'schedule': {'id': 47570,
#    'startTime': '2018-10-17T00:00:00.000Z',
#    'endedTime': None,
#    'awayTeam': {'id': 85, 'abbreviation': 'PHI'},
#    'homeTeam': {'id': 82, 'abbreviation': 'BOS'},
#    'venue': {'id': 27, 'name': 'TD Garden'},
#    'venueAllegiance': 'HOME',
#    'scheduleStatus': 'NORMAL',
#    'originalStartTime': None,
#    'delayedOrPostponedReason': None,
#    'playedStatus': 'COMPLETED',
#    'attendance': None,
#    'officials': [],
#    'broadcasters': [],
#    'weather': None},
#   'score': {'currentQuarter': None,
#    'currentQuarterSecondsRemaining': None,
#    'currentIntermission': None,
#    'awayScoreTotal': 87,
#    'homeScoreTotal': 105,
#    'quarters': [{'quarterNumber': 1, 'awayScore': 21, 'homeScore': 21},
#     {'quarterNumber': 2, 'awayScore': 21, 'homeScore': 26},
#     {'quarterNumber': 3, 'awayScore': 24, 'homeScore': 30},
#     {'quarterNumber': 4, 'awayScore': 21, 'homeScore': 28}]}},
#  {'schedule': {'id': 47571,
#    'startTime': '2018-10-17T02:30:00.000Z',
#    'endedTime': None,
#    'awayTeam': {'id': 96, 'abbreviation': 'OKL'},
#    'homeTeam': {'id': 101, 'abbreviation': 'GSW'},
#    'venue': {'id': 95, 'name': 'Oracle Arena'},
#    'venueAllegiance': 'HOME',
#    'scheduleStatus': 'NORMAL',
#    'originalStartTime': None,
#    'delayedOrPostponedReason': None,
#    'playedStatus': 'COMPLETED',
#    'attendance': None,
#    'officials': [],
#    'broadcasters': [],
#    'weather': None},
#   'score': {'currentQuarter': None,
#    'currentQuarterSecondsRemaining': None,
#    'currentIntermission': None,
#    'awayScoreTotal': 100,
#    'homeScoreTotal': 108,
#    'quarters': [{'quarterNumber': 1, 'awayScore': 23, 'homeScore': 31},
#     {'quarterNumber': 2, 'awayScore': 24, 'homeScore': 26},
#     {'quarterNumber': 3, 'awayScore': 32, 'homeScore': 26},
#     {'quarterNumber': 4, 'awayScore': 21, 'homeScore': 25}]}},
#  {'schedule': {'id': 47572,
#    'startTime': '2018-10-17T23:00:00.000Z',
#    'endedTime': None,
#    'awayTeam': {'id': 90, 'abbreviation': 'MIL'},
#    'homeTeam': {'id': 93, 'abbreviation': 'CHA'},
#    'venue': {'id': 87, 'name': 'Spectrum Center'},
#    'venueAllegiance': 'HOME',
#    'scheduleStatus': 'NORMAL',
#    'originalStartTime': None,
#    'delayedOrPostponedReason': None,
#    'playedStatus': 'COMPLETED',
#    'attendance': None,
#    'officials': [],
#    'broadcasters': [],
#    'weather': None},
#   'score': {'currentQuarter': None,
#    'currentQuarterSecondsRemaining': None,
#    'currentIntermission': None,
#    'awayScoreTotal': 113,
#    'homeScoreTotal': 112,
#    'quarters': [{'quarterNumber': 1, 'awayScore': 36, 'homeScore': 23},
#     {'quarterNumber': 2, 'awayScore': 31, 'homeScore': 31},
#     {'quarterNumber': 3, 'awayScore': 26, 'homeScore': 29},
#     {'quarterNumber': 4, 'awayScore': 20, 'homeScore': 29}]}},
#  {'schedule': {'id': 47573,
#    'startTime': '2018-10-17T23:00:00.000Z',
#    'endedTime': None,
#    'awayTeam': {'id': 84, 'abbreviation': 'BRO'},
#    'homeTeam': {'id': 88, 'abbreviation': 'DET'},
#    'venue': {'id': 145, 'name': 'Little Caesars Arena'},
#    'venueAllegiance': 'HOME',
#    'scheduleStatus': 'NORMAL',
#    'originalStartTime': None,
#    'delayedOrPostponedReason': None,
#    'playedStatus': 'COMPLETED',
#    'attendance': None,
#    'officials': [],
#    'broadcasters': [],
#    'weather': None},
#   'score': {'currentQuarter': None,
#    'currentQuarterSecondsRemaining': None,
#    'currentIntermission': None,
#    'awayScoreTotal': 100,
#    'homeScoreTotal': 103,
#    'quarters': [{'quarterNumber': 1, 'awayScore': 29, 'homeScore': 24},
#     {'quarterNumber': 2, 'awayScore': 22, 'homeScore': 27},
#     {'quarterNumber': 3, 'awayScore': 25, 'homeScore': 32},
#     {'quarterNumber': 4, 'awayScore': 24, 'homeScore': 20}]}},
#  {'schedule': {'id': 47574,
#    'startTime': '2018-10-17T23:00:00.000Z',
#    'endedTime': None,
#    'awayTeam': {'id': 107, 'abbreviation': 'MEM'},
#    'homeTeam': {'id': 87, 'abbreviation': 'IND'},
#    'venue': {'id': 81, 'name': 'Bankers Life Fieldhouse'},
#    'venueAllegiance': 'HOME',
#    'scheduleStatus': 'NORMAL',
#    'originalStartTime': None,
#    'delayedOrPostponedReason': None,
#    'playedStatus': 'COMPLETED',
#    'attendance': None,
#    'officials': [],
#    'broadcasters': [],
#    'weather': None},
#   'score': {'currentQuarter': None,
#    'currentQuarterSecondsRemaining': None,
#    'currentIntermission': None,
#    'awayScoreTotal': 83,
#    'homeScoreTotal': 111,
#    'quarters': [{'quarterNumber': 1, 'awayScore': 16, 'homeScore': 27},
#     {'quarterNumber': 2, 'awayScore': 23, 'homeScore': 29},
#     {'quarterNumber': 3, 'awayScore': 19, 'homeScore': 20},
#     {'quarterNumber': 4, 'awayScore': 25, 'homeScore': 35}]}},
#  {'schedule': {'id': 47575,
#    'startTime': '2018-10-17T23:00:00.000Z',
#    'endedTime': None,
#    'awayTeam': {'id': 92, 'abbreviation': 'MIA'},
#    'homeTeam': {'id': 95, 'abbreviation': 'ORL'},
#    'venue': {'id': 89, 'name': 'Amway Center'},
#    'venueAllegiance': 'HOME',
#    'scheduleStatus': 'NORMAL',
#    'originalStartTime': None,
#    'delayedOrPostponedReason': None,
#    'playedStatus': 'COMPLETED',
#    'attendance': None,
#    'officials': [],
#    'broadcasters': [],
#    'weather': None},
#   'score': {'currentQuarter': None,
#    'currentQuarterSecondsRemaining': None,
#    'currentIntermission': None,
#    'awayScoreTotal': 101,
#    'homeScoreTotal': 104,
#    'quarters': [{'quarterNumber': 1, 'awayScore': 31, 'homeScore': 25},
#     {'quarterNumber': 2, 'awayScore': 20, 'homeScore': 29},
#     {'quarterNumber': 3, 'awayScore': 27, 'homeScore': 25},
#     {'quarterNumber': 4, 'awayScore': 23, 'homeScore': 25}]}},
#  {'schedule': {'id': 47576,
#    'startTime': '2018-10-17T23:30:00.000Z',
#    'endedTime': None,
#    'awayTeam': {'id': 91, 'abbreviation': 'ATL'},
#    'homeTeam': {'id': 83, 'abbreviation': 'NYK'},
#    'venue': {'id': 12, 'name': 'Madison Square Garden'},
#    'venueAllegiance': 'HOME',
#    'scheduleStatus': 'NORMAL',
#    'originalStartTime': None,
#    'delayedOrPostponedReason': None,
#    'playedStatus': 'COMPLETED',
#    'attendance': None,
#    'officials': [],
#    'broadcasters': [],
#    'weather': None},
#   'score': {'currentQuarter': None,
#    'currentQuarterSecondsRemaining': None,
#    'currentIntermission': None,
#    'awayScoreTotal': 107,
#    'homeScoreTotal': 126,
#    'quarters': [{'quarterNumber': 1, 'awayScore': 24, 'homeScore': 23},
#     {'quarterNumber': 2, 'awayScore': 25, 'homeScore': 49},
#     {'quarterNumber': 3, 'awayScore': 35, 'homeScore': 34},
#     {'quarterNumber': 4, 'awayScore': 23, 'homeScore': 20}]}},
#  {'schedule': {'id': 47577,
#    'startTime': '2018-10-17T23:30:00.000Z',
#    'endedTime': None,
#    'awayTeam': {'id': 86, 'abbreviation': 'CLE'},
#    'homeTeam': {'id': 81, 'abbreviation': 'TOR'},
#    'venue': {'id': 1, 'name': 'Scotiabank Arena'},
#    'venueAllegiance': 'HOME',
#    'scheduleStatus': 'NORMAL',
#    'originalStartTime': None,
#    'delayedOrPostponedReason': None,
#    'playedStatus': 'COMPLETED',
#    'attendance': None,
#    'officials': [],
#    'broadcasters': [],
#    'weather': None},
#   'score': {'currentQuarter': None,
#    'currentQuarterSecondsRemaining': None,
#    'currentIntermission': None,
#    'awayScoreTotal': 104,
#    'homeScoreTotal': 116,
#    'quarters': [{'quarterNumber': 1, 'awayScore': 25, 'homeScore': 28},
#     {'quarterNumber': 2, 'awayScore': 22, 'homeScore': 32},
#     {'quarterNumber': 3, 'awayScore': 28, 'homeScore': 30},
#     {'quarterNumber': 4, 'awayScore': 29, 'homeScore': 26}]}},
#  {'schedule': {'id': 47578,
#    'startTime': '2018-10-18T00:00:00.000Z',
#    'endedTime': None,
#    'awayTeam': {'id': 110, 'abbreviation': 'NOP'},
#    'homeTeam': {'id': 109, 'abbreviation': 'HOU'},
#    'venue': {'id': 102, 'name': 'Toyota Center'},
#    'venueAllegiance': 'HOME',
#    'scheduleStatus': 'NORMAL',
#    'originalStartTime': None,
#    'delayedOrPostponedReason': None,
#    'playedStatus': 'COMPLETED',
#    'attendance': None,
#    'officials': [],
#    'broadcasters': [],
#    'weather': None},
#   'score': {'currentQuarter': None,
#    'currentQuarterSecondsRemaining': None,
#    'currentIntermission': None,
#    'awayScoreTotal': 131,
#    'homeScoreTotal': 112,
#    'quarters': [{'quarterNumber': 1, 'awayScore': 35, 'homeScore': 29},
#     {'quarterNumber': 2, 'awayScore': 36, 'homeScore': 25},
#     {'quarterNumber': 3, 'awayScore': 30, 'homeScore': 30},
#     {'quarterNumber': 4, 'awayScore': 30, 'homeScore': 28}]}},
#  {'schedule': {'id': 47579,
#    'startTime': '2018-10-18T00:30:00.000Z',
#    'endedTime': None,
#    'awayTeam': {'id': 100, 'abbreviation': 'MIN'},
#    'homeTeam': {'id': 106, 'abbreviation': 'SAS'},
#    'venue': {'id': 99, 'name': 'AT&T Center'},
#    'venueAllegiance': 'HOME',
#    'scheduleStatus': 'NORMAL',
#    'originalStartTime': None,
#    'delayedOrPostponedReason': None,
#    'playedStatus': 'COMPLETED',
#    'attendance': None,
#    'officials': [],
#    'broadcasters': [],
#    'weather': None},
#   'score': {'currentQuarter': None,
#    'currentQuarterSecondsRemaining': None,
#    'currentIntermission': None,
#    'awayScoreTotal': 108,
#    'homeScoreTotal': 112,
#    'quarters': [{'quarterNumber': 1, 'awayScore': 23, 'homeScore': 31},
#     {'quarterNumber': 2, 'awayScore': 29, 'homeScore': 25},
#     {'quarterNumber': 3, 'awayScore': 31, 'homeScore': 25},
#     {'quarterNumber': 4, 'awayScore': 25, 'homeScore': 31}]}},
#  {'schedule': {'id': 47580,
#    'startTime': '2018-10-18T02:00:00.000Z',
#    'endedTime': None,
#    'awayTeam': {'id': 98, 'abbreviation': 'UTA'},
#    'homeTeam': {'id': 103, 'abbreviation': 'SAC'},
#    'venue': {'id': 151, 'name': 'Golden 1 Center'},
#    'venueAllegiance': 'HOME',
#    'scheduleStatus': 'NORMAL',
#    'originalStartTime': None,
#    'delayedOrPostponedReason': None,
#    'playedStatus': 'COMPLETED',
#    'attendance': None,
#    'officials': [],
#    'broadcasters': [],
#    'weather': None},
#   'score': {'currentQuarter': None,
#    'currentQuarterSecondsRemaining': None,
#    'currentIntermission': None,
#    'awayScoreTotal': 123,
#    'homeScoreTotal': 117,
#    'quarters': [{'quarterNumber': 1, 'awayScore': 30, 'homeScore': 34},
#     {'quarterNumber': 2, 'awayScore': 38, 'homeScore': 21},
#     {'quarterNumber': 3, 'awayScore': 25, 'homeScore': 32},
#     {'quarterNumber': 4, 'awayScore': 30, 'homeScore': 30}]}},
#  {'schedule': {'id': 47581,
#    'startTime': '2018-10-18T02:30:00.000Z',
#    'endedTime': None,
#    'awayTeam': {'id': 99, 'abbreviation': 'DEN'},
#    'homeTeam': {'id': 102, 'abbreviation': 'LAC'},
#    'venue': {'id': 25, 'name': 'Staples Center'},
#    'venueAllegiance': 'HOME',
#    'scheduleStatus': 'NORMAL',
#    'originalStartTime': None,
#    'delayedOrPostponedReason': None,
#    'playedStatus': 'COMPLETED',
#    'attendance': None,
#    'officials': [],
#    'broadcasters': [],
#    'weather': None},
#   'score': {'currentQuarter': None,
#    'currentQuarterSecondsRemaining': None,
#    'currentIntermission': None,
#    'awayScoreTotal': 107,
#    'homeScoreTotal': 98,
#    'quarters': [{'quarterNumber': 1, 'awayScore': 29, 'homeScore': 24},
#     {'quarterNumber': 2, 'awayScore': 30, 'homeScore': 30},
#     {'quarterNumber': 3, 'awayScore': 15, 'homeScore': 18},
#     {'quarterNumber': 4, 'awayScore': 33, 'homeScore': 26}]}},
#  {'schedule': {'id': 47582,
#    'startTime': '2018-10-18T02:30:00.000Z',
#    'endedTime': None,
#    'awayTeam': {'id': 108, 'abbreviation': 'DAL'},
#    'homeTeam': {'id': 104, 'abbreviation': 'PHX'},
#    'venue': {'id': 98, 'name': 'Talking Stick Resort Arena'},
#    'venueAllegiance': 'HOME',
#    'scheduleStatus': 'NORMAL',
#    'originalStartTime': None,
#    'delayedOrPostponedReason': None,
#    'playedStatus': 'COMPLETED',
#    'attendance': None,
#    'officials': [],
#    'broadcasters': [],
#    'weather': None},
#   'score': {'currentQuarter': None,
#    'currentQuarterSecondsRemaining': None,
#    'currentIntermission': None,
#    'awayScoreTotal': 100,
#    'homeScoreTotal': 121,
#    'quarters': [{'quarterNumber': 1, 'awayScore': 24, 'homeScore': 37},
#     {'quarterNumber': 2, 'awayScore': 22, 'homeScore': 19},
#     {'quarterNumber': 3, 'awayScore': 27, 'homeScore': 27},
#     {'quarterNumber': 4, 'awayScore': 27, 'homeScore': 38}]}},
#  {'schedule': {'id': 47583,
#    'startTime': '2018-10-19T00:00:00.000Z',
#    'endedTime': None,
#    'awayTeam': {'id': 89, 'abbreviation': 'CHI'},
#    'homeTeam': {'id': 85, 'abbreviation': 'PHI'},
#    'venue': {'id': 29, 'name': 'Wells Fargo Center'},
#    'venueAllegiance': 'HOME',
#    'scheduleStatus': 'NORMAL',
#    'originalStartTime': None,
#    'delayedOrPostponedReason': None,
#    'playedStatus': 'COMPLETED',
#    'attendance': None,
#    'officials': [],
#    'broadcasters': [],
#    'weather': None},
#   'score': {'currentQuarter': None,
#    'currentQuarterSecondsRemaining': None,
#    'currentIntermission': None,
#    'awayScoreTotal': 108,
#    'homeScoreTotal': 127,
#    'quarters': [{'quarterNumber': 1, 'awayScore': 41, 'homeScore': 38},
#     {'quarterNumber': 2, 'awayScore': 17, 'homeScore': 27},
#     {'quarterNumber': 3, 'awayScore': 18, 'homeScore': 37},
#     {'quarterNumber': 4, 'awayScore': 32, 'homeScore': 25}]}},
#  {'schedule': {'id': 47584,
#    'startTime': '2018-10-19T00:00:00.000Z',
#    'endedTime': None,
#    'awayTeam': {'id': 92, 'abbreviation': 'MIA'},
#    'homeTeam': {'id': 94, 'abbreviation': 'WAS'},
#    'venue': {'id': 13, 'name': 'Capital One Arena'},
#    'venueAllegiance': 'HOME',
#    'scheduleStatus': 'NORMAL',
#    'originalStartTime': None,
#    'delayedOrPostponedReason': None,
#    'playedStatus': 'COMPLETED',
#    'attendance': None,
#    'officials': [],
#    'broadcasters': [],
#    'weather': None},
#   'score': {'currentQuarter': None,
#    'currentQuarterSecondsRemaining': None,
#    'currentIntermission': None,
#    'awayScoreTotal': 113,
#    'homeScoreTotal': 112,
#    'quarters': [{'quarterNumber': 1, 'awayScore': 24, 'homeScore': 25},
#     {'quarterNumber': 2, 'awayScore': 34, 'homeScore': 34},
#     {'quarterNumber': 3, 'awayScore': 27, 'homeScore': 30},
#     {'quarterNumber': 4, 'awayScore': 28, 'homeScore': 23}]}},
#  {'schedule': {'id': 47585,
#    'startTime': '2018-10-19T02:30:00.000Z',
#    'endedTime': None,
#    'awayTeam': {'id': 105, 'abbreviation': 'LAL'},
#    'homeTeam': {'id': 97, 'abbreviation': 'POR'},
#    'venue': {'id': 91, 'name': 'Moda Center'},
#    'venueAllegiance': 'HOME',
#    'scheduleStatus': 'NORMAL',
#    'originalStartTime': None,
#    'delayedOrPostponedReason': None,
#    'playedStatus': 'COMPLETED',
#    'attendance': None,
#    'officials': [],
#    'broadcasters': [],
#    'weather': None},
#   'score': {'currentQuarter': None,
#    'currentQuarterSecondsRemaining': None,
#    'currentIntermission': None,
#    'awayScoreTotal': 119,
#    'homeScoreTotal': 128,
#    'quarters': [{'quarterNumber': 1, 'awayScore': 31, 'homeScore': 34},
#     {'quarterNumber': 2, 'awayScore': 32, 'homeScore': 31},
#     {'quarterNumber': 3, 'awayScore': 28, 'homeScore': 28},
#     {'quarterNumber': 4, 'awayScore': 28, 'homeScore': 35}]}},
#  {'schedule': {'id': 47586,
#    'startTime': '2018-10-19T23:00:00.000Z',
#    'endedTime': None,
#    'awayTeam': {'id': 93, 'abbreviation': 'CHA'},
#    'homeTeam': {'id': 95, 'abbreviation': 'ORL'},
#    'venue': {'id': 89, 'name': 'Amway Center'},
#    'venueAllegiance': 'HOME',
#    'scheduleStatus': 'NORMAL',
#    'originalStartTime': None,
#    'delayedOrPostponedReason': None,
#    'playedStatus': 'COMPLETED',
#    'attendance': None,
#    'officials': [],
#    'broadcasters': [],
#    'weather': None},
#   'score': {'currentQuarter': None,
#    'currentQuarterSecondsRemaining': None,
#    'currentIntermission': None,
#    'awayScoreTotal': 120,
#    'homeScoreTotal': 88,
#    'quarters': [{'quarterNumber': 1, 'awayScore': 22, 'homeScore': 10},
#     {'quarterNumber': 2, 'awayScore': 29, 'homeScore': 21},
#     {'quarterNumber': 3, 'awayScore': 31, 'homeScore': 23},
#     {'quarterNumber': 4, 'awayScore': 38, 'homeScore': 34}]}},
#  {'schedule': {'id': 47587,
#    'startTime': '2018-10-19T23:30:00.000Z',
#    'endedTime': None,
#    'awayTeam': {'id': 83, 'abbreviation': 'NYK'},
#    'homeTeam': {'id': 84, 'abbreviation': 'BRO'},
#    'venue': {'id': 78, 'name': 'Barclays Center'},
#    'venueAllegiance': 'HOME',
#    'scheduleStatus': 'NORMAL',
#    'originalStartTime': None,
#    'delayedOrPostponedReason': None,
#    'playedStatus': 'COMPLETED',
#    'attendance': None,
#    'officials': [],
#    'broadcasters': [],
#    'weather': None},
#   'score': {'currentQuarter': None,
#    'currentQuarterSecondsRemaining': None,
#    'currentIntermission': None,
#    'awayScoreTotal': 105,
#    'homeScoreTotal': 107,
#    'quarters': [{'quarterNumber': 1, 'awayScore': 24, 'homeScore': 33},
#     {'quarterNumber': 2, 'awayScore': 26, 'homeScore': 24},
#     {'quarterNumber': 3, 'awayScore': 26, 'homeScore': 17},
#     {'quarterNumber': 4, 'awayScore': 29, 'homeScore': 33}]}},
#  {'schedule': {'id': 47588,
#    'startTime': '2018-10-20T00:00:00.000Z',
#    'endedTime': None,
#    'awayTeam': {'id': 82, 'abbreviation': 'BOS'},
#    'homeTeam': {'id': 81, 'abbreviation': 'TOR'},
#    'venue': {'id': 1, 'name': 'Scotiabank Arena'},
#    'venueAllegiance': 'HOME',
#    'scheduleStatus': 'NORMAL',
#    'originalStartTime': None,
#    'delayedOrPostponedReason': None,
#    'playedStatus': 'COMPLETED',
#    'attendance': None,
#    'officials': [],
#    'broadcasters': [],
#    'weather': None},
#   'score': {'currentQuarter': None,
#    'currentQuarterSecondsRemaining': None,
#    'currentIntermission': None,
#    'awayScoreTotal': 101,
#    'homeScoreTotal': 113,
#    'quarters': [{'quarterNumber': 1, 'awayScore': 25, 'homeScore': 18},
#     {'quarterNumber': 2, 'awayScore': 28, 'homeScore': 31},
#     {'quarterNumber': 3, 'awayScore': 26, 'homeScore': 33},
#     {'quarterNumber': 4, 'awayScore': 22, 'homeScore': 31}]}},
#  {'schedule': {'id': 47589,
#    'startTime': '2018-10-20T00:00:00.000Z',
#    'endedTime': None,
#    'awayTeam': {'id': 91, 'abbreviation': 'ATL'},
#    'homeTeam': {'id': 107, 'abbreviation': 'MEM'},
#    'venue': {'id': 100, 'name': 'FedEx Forum'},
#    'venueAllegiance': 'HOME',
#    'scheduleStatus': 'NORMAL',
#    'originalStartTime': None,
#    'delayedOrPostponedReason': None,
#    'playedStatus': 'COMPLETED',
#    'attendance': None,
#    'officials': [],
#    'broadcasters': [],
#    'weather': None},
#   'score': {'currentQuarter': None,
#    'currentQuarterSecondsRemaining': None,
#    'currentIntermission': None,
#    'awayScoreTotal': 117,
#    'homeScoreTotal': 131,
#    'quarters': [{'quarterNumber': 1, 'awayScore': 33, 'homeScore': 37},
#     {'quarterNumber': 2, 'awayScore': 28, 'homeScore': 40},
#     {'quarterNumber': 3, 'awayScore': 21, 'homeScore': 29},
#     {'quarterNumber': 4, 'awayScore': 35, 'homeScore': 25}]}},
#  {'schedule': {'id': 47590,
#    'startTime': '2018-10-20T00:00:00.000Z',
#    'endedTime': None,
#    'awayTeam': {'id': 86, 'abbreviation': 'CLE'},
#    'homeTeam': {'id': 100, 'abbreviation': 'MIN'},
#    'venue': {'id': 94, 'name': 'Target Center'},
#    'venueAllegiance': 'HOME',
#    'scheduleStatus': 'NORMAL',
#    'originalStartTime': None,
#    'delayedOrPostponedReason': None,
#    'playedStatus': 'COMPLETED',
#    'attendance': None,
#    'officials': [],
#    'broadcasters': [],
#    'weather': None},
#   'score': {'currentQuarter': None,
#    'currentQuarterSecondsRemaining': None,
#    'currentIntermission': None,
#    'awayScoreTotal': 123,
#    'homeScoreTotal': 131,
#    'quarters': [{'quarterNumber': 1, 'awayScore': 30, 'homeScore': 32},
#     {'quarterNumber': 2, 'awayScore': 24, 'homeScore': 39},
#     {'quarterNumber': 3, 'awayScore': 41, 'homeScore': 33},
#     {'quarterNumber': 4, 'awayScore': 28, 'homeScore': 27}]}},
#  {'schedule': {'id': 47591,
#    'startTime': '2018-10-20T00:00:00.000Z',
#    'endedTime': None,
#    'awayTeam': {'id': 103, 'abbreviation': 'SAC'},
#    'homeTeam': {'id': 110, 'abbreviation': 'NOP'},
#    'venue': {'id': 103, 'name': 'Smoothie King Center'},
#    'venueAllegiance': 'HOME',
#    'scheduleStatus': 'NORMAL',
#    'originalStartTime': None,
#    'delayedOrPostponedReason': None,
#    'playedStatus': 'COMPLETED',
#    'attendance': None,
#    'officials': [],
#    'broadcasters': [],
#    'weather': None},
#   'score': {'currentQuarter': None,
#    'currentQuarterSecondsRemaining': None,
#    'currentIntermission': None,
#    'awayScoreTotal': 129,
#    'homeScoreTotal': 149,
#    'quarters': [{'quarterNumber': 1, 'awayScore': 32, 'homeScore': 40},
#     {'quarterNumber': 2, 'awayScore': 31, 'homeScore': 32},
#     {'quarterNumber': 3, 'awayScore': 27, 'homeScore': 38},
#     {'quarterNumber': 4, 'awayScore': 39, 'homeScore': 39}]}},
#  {'schedule': {'id': 47592,
#    'startTime': '2018-10-20T00:30:00.000Z',
#    'endedTime': None,
#    'awayTeam': {'id': 87, 'abbreviation': 'IND'},
#    'homeTeam': {'id': 90, 'abbreviation': 'MIL'},
#    'venue': {'id': 152, 'name': 'Fiserv Forum'},
#    'venueAllegiance': 'HOME',
#    'scheduleStatus': 'NORMAL',
#    'originalStartTime': None,
#    'delayedOrPostponedReason': None,
#    'playedStatus': 'COMPLETED',
#    'attendance': None,
#    'officials': [],
#    'broadcasters': [],
#    'weather': None},
#   'score': {'currentQuarter': None,
#    'currentQuarterSecondsRemaining': None,
#    'currentIntermission': None,
#    'awayScoreTotal': 101,
#    'homeScoreTotal': 118,
#    'quarters': [{'quarterNumber': 1, 'awayScore': 25, 'homeScore': 30},
#     {'quarterNumber': 2, 'awayScore': 28, 'homeScore': 32},
#     {'quarterNumber': 3, 'awayScore': 23, 'homeScore': 31},
#     {'quarterNumber': 4, 'awayScore': 25, 'homeScore': 25}]}},
#  {'schedule': {'id': 47593,
#    'startTime': '2018-10-20T02:30:00.000Z',
#    'endedTime': None,
#    'awayTeam': {'id': 101, 'abbreviation': 'GSW'},
#    'homeTeam': {'id': 98, 'abbreviation': 'UTA'},
#    'venue': {'id': 92, 'name': 'Vivint Smart Home Arena'},
#    'venueAllegiance': 'HOME',
#    'scheduleStatus': 'NORMAL',
#    'originalStartTime': None,
#    'delayedOrPostponedReason': None,
#    'playedStatus': 'COMPLETED',
#    'attendance': None,
#    'officials': [],
#    'broadcasters': [],
#    'weather': None},
#   'score': {'currentQuarter': None,
#    'currentQuarterSecondsRemaining': None,
#    'currentIntermission': None,
#    'awayScoreTotal': 124,
#    'homeScoreTotal': 123,
#    'quarters': [{'quarterNumber': 1, 'awayScore': 32, 'homeScore': 34},
#     {'quarterNumber': 2, 'awayScore': 37, 'homeScore': 47},
#     {'quarterNumber': 3, 'awayScore': 28, 'homeScore': 22},
#     {'quarterNumber': 4, 'awayScore': 27, 'homeScore': 20}]}},
#  {'schedule': {'id': 47594,
#    'startTime': '2018-10-20T02:30:00.000Z',
#    'endedTime': None,
#    'awayTeam': {'id': 96, 'abbreviation': 'OKL'},
#    'homeTeam': {'id': 102, 'abbreviation': 'LAC'},
#    'venue': {'id': 25, 'name': 'Staples Center'},
#    'venueAllegiance': 'HOME',
#    'scheduleStatus': 'NORMAL',
#    'originalStartTime': None,
#    'delayedOrPostponedReason': None,
#    'playedStatus': 'COMPLETED',
#    'attendance': None,
#    'officials': [],
#    'broadcasters': [],
#    'weather': None},
#   'score': {'currentQuarter': None,
#    'currentQuarterSecondsRemaining': None,
#    'currentIntermission': None,
#    'awayScoreTotal': 92,
#    'homeScoreTotal': 108,
#    'quarters': [{'quarterNumber': 1, 'awayScore': 20, 'homeScore': 27},
#     {'quarterNumber': 2, 'awayScore': 26, 'homeScore': 21},
#     {'quarterNumber': 3, 'awayScore': 31, 'homeScore': 23},
#     {'quarterNumber': 4, 'awayScore': 15, 'homeScore': 37}]}},
#  {'schedule': {'id': 47595,
#    'startTime': '2018-10-20T23:00:00.000Z',
#    'endedTime': None,
#    'awayTeam': {'id': 84, 'abbreviation': 'BRO'},
#    'homeTeam': {'id': 87, 'abbreviation': 'IND'},
#    'venue': {'id': 81, 'name': 'Bankers Life Fieldhouse'},
#    'venueAllegiance': 'HOME',
#    'scheduleStatus': 'NORMAL',
#    'originalStartTime': None,
#    'delayedOrPostponedReason': None,
#    'playedStatus': 'COMPLETED',
#    'attendance': None,
#    'officials': [],
#    'broadcasters': [],
#    'weather': None},
#   'score': {'currentQuarter': None,
#    'currentQuarterSecondsRemaining': None,
#    'currentIntermission': None,
#    'awayScoreTotal': 112,
#    'homeScoreTotal': 132,
#    'quarters': [{'quarterNumber': 1, 'awayScore': 29, 'homeScore': 33},
#     {'quarterNumber': 2, 'awayScore': 29, 'homeScore': 34},
#     {'quarterNumber': 3, 'awayScore': 27, 'homeScore': 28},
#     {'quarterNumber': 4, 'awayScore': 27, 'homeScore': 37}]}},
#  {'schedule': {'id': 47596,
#    'startTime': '2018-10-20T23:00:00.000Z',
#    'endedTime': None,
#    'awayTeam': {'id': 81, 'abbreviation': 'TOR'},
#    'homeTeam': {'id': 94, 'abbreviation': 'WAS'},
#    'venue': {'id': 13, 'name': 'Capital One Arena'},
#    'venueAllegiance': 'HOME',
#    'scheduleStatus': 'NORMAL',
#    'originalStartTime': None,
#    'delayedOrPostponedReason': None,
#    'playedStatus': 'COMPLETED',
#    'attendance': None,
#    'officials': [],
#    'broadcasters': [],
#    'weather': None},
#   'score': {'currentQuarter': None,
#    'currentQuarterSecondsRemaining': None,
#    'currentIntermission': None,
#    'awayScoreTotal': 117,
#    'homeScoreTotal': 113,
#    'quarters': [{'quarterNumber': 1, 'awayScore': 24, 'homeScore': 22},
#     {'quarterNumber': 2, 'awayScore': 33, 'homeScore': 32},
#     {'quarterNumber': 3, 'awayScore': 33, 'homeScore': 28},
#     {'quarterNumber': 4, 'awayScore': 27, 'homeScore': 31}]}},
#  {'schedule': {'id': 47597,
#    'startTime': '2018-10-20T23:30:00.000Z',
#    'endedTime': None,
#    'awayTeam': {'id': 82, 'abbreviation': 'BOS'},
#    'homeTeam': {'id': 83, 'abbreviation': 'NYK'},
#    'venue': {'id': 12, 'name': 'Madison Square Garden'},
#    'venueAllegiance': 'HOME',
#    'scheduleStatus': 'NORMAL',
#    'originalStartTime': None,
#    'delayedOrPostponedReason': None,
#    'playedStatus': 'COMPLETED',
#    'attendance': None,
#    'officials': [],
#    'broadcasters': [],
#    'weather': None},
#   'score': {'currentQuarter': None,
#    'currentQuarterSecondsRemaining': None,
#    'currentIntermission': None,
#    'awayScoreTotal': 103,
#    'homeScoreTotal': 101,
#    'quarters': [{'quarterNumber': 1, 'awayScore': 31, 'homeScore': 18},
#     {'quarterNumber': 2, 'awayScore': 19, 'homeScore': 30},
#     {'quarterNumber': 3, 'awayScore': 27, 'homeScore': 22},
#     {'quarterNumber': 4, 'awayScore': 26, 'homeScore': 31}]}},
#  {'schedule': {'id': 47598,
#    'startTime': '2018-10-20T23:30:00.000Z',
#    'endedTime': None,
#    'awayTeam': {'id': 95, 'abbreviation': 'ORL'},
#    'homeTeam': {'id': 85, 'abbreviation': 'PHI'},
#    'venue': {'id': 29, 'name': 'Wells Fargo Center'},
#    'venueAllegiance': 'HOME',
#    'scheduleStatus': 'NORMAL',
#    'originalStartTime': None,
#    'delayedOrPostponedReason': None,
#    'playedStatus': 'COMPLETED',
#    'attendance': None,
#    'officials': [],
#    'broadcasters': [],
#    'weather': None},
#   'score': {'currentQuarter': None,
#    'currentQuarterSecondsRemaining': None,
#    'currentIntermission': None,
#    'awayScoreTotal': 115,
#    'homeScoreTotal': 116,
#    'quarters': [{'quarterNumber': 1, 'awayScore': 32, 'homeScore': 30},
#     {'quarterNumber': 2, 'awayScore': 20, 'homeScore': 33},
#     {'quarterNumber': 3, 'awayScore': 34, 'homeScore': 26},
#     {'quarterNumber': 4, 'awayScore': 29, 'homeScore': 27}]}},
#  {'schedule': {'id': 47599,
#    'startTime': '2018-10-21T00:00:00.000Z',
#    'endedTime': None,
#    'awayTeam': {'id': 93, 'abbreviation': 'CHA'},
#    'homeTeam': {'id': 92, 'abbreviation': 'MIA'},
#    'venue': {'id': 86, 'name': 'American Airlines Arena'},
#    'venueAllegiance': 'HOME',
#    'scheduleStatus': 'NORMAL',
#    'originalStartTime': None,
#    'delayedOrPostponedReason': None,
#    'playedStatus': 'COMPLETED',
#    'attendance': None,
#    'officials': [],
#    'broadcasters': [],
#    'weather': None},
#   'score': {'currentQuarter': None,
#    'currentQuarterSecondsRemaining': None,
#    'currentIntermission': None,
#    'awayScoreTotal': 113,
#    'homeScoreTotal': 112,
#    'quarters': [{'quarterNumber': 1, 'awayScore': 34, 'homeScore': 29},
#     {'quarterNumber': 2, 'awayScore': 38, 'homeScore': 23},
#     {'quarterNumber': 3, 'awayScore': 20, 'homeScore': 30},
#     {'quarterNumber': 4, 'awayScore': 21, 'homeScore': 30}]}},
#  {'schedule': {'id': 47600,
#    'startTime': '2018-10-21T00:00:00.000Z',
#    'endedTime': None,
#    'awayTeam': {'id': 88, 'abbreviation': 'DET'},
#    'homeTeam': {'id': 89, 'abbreviation': 'CHI'},
#    'venue': {'id': 28, 'name': 'United Center'},
#    'venueAllegiance': 'HOME',
#    'scheduleStatus': 'NORMAL',
#    'originalStartTime': None,
#    'delayedOrPostponedReason': None,
#    'playedStatus': 'COMPLETED',
#    'attendance': None,
#    'officials': [],
#    'broadcasters': [],
#    'weather': None},
#   'score': {'currentQuarter': None,
#    'currentQuarterSecondsRemaining': None,
#    'currentIntermission': None,
#    'awayScoreTotal': 118,
#    'homeScoreTotal': 116,
#    'quarters': [{'quarterNumber': 1, 'awayScore': 25, 'homeScore': 27},
#     {'quarterNumber': 2, 'awayScore': 35, 'homeScore': 31},
#     {'quarterNumber': 3, 'awayScore': 25, 'homeScore': 26},
#     {'quarterNumber': 4, 'awayScore': 33, 'homeScore': 32}]}},
#  {'schedule': {'id': 47601,
#    'startTime': '2018-10-21T00:30:00.000Z',
#    'endedTime': None,
#    'awayTeam': {'id': 100, 'abbreviation': 'MIN'},
#    'homeTeam': {'id': 108, 'abbreviation': 'DAL'},
#    'venue': {'id': 2, 'name': 'American Airlines Center'},
#    'venueAllegiance': 'HOME',
#    'scheduleStatus': 'NORMAL',
#    'originalStartTime': None,
#    'delayedOrPostponedReason': None,
#    'playedStatus': 'COMPLETED',
#    'attendance': None,
#    'officials': [],
#    'broadcasters': [],
#    'weather': None},
#   'score': {'currentQuarter': None,
#    'currentQuarterSecondsRemaining': None,
#    'currentIntermission': None,
#    'awayScoreTotal': 136,
#    'homeScoreTotal': 140,
#    'quarters': [{'quarterNumber': 1, 'awayScore': 46, 'homeScore': 37},
#     {'quarterNumber': 2, 'awayScore': 23, 'homeScore': 32},
#     {'quarterNumber': 3, 'awayScore': 30, 'homeScore': 28},
#     {'quarterNumber': 4, 'awayScore': 37, 'homeScore': 43}]}},
#  {'schedule': {'id': 47602,
#    'startTime': '2018-10-21T01:00:00.000Z',
#    'endedTime': None,
#    'awayTeam': {'id': 104, 'abbreviation': 'PHX'},
#    'homeTeam': {'id': 99, 'abbreviation': 'DEN'},
#    'venue': {'id': 19, 'name': 'Pepsi Center'},
#    'venueAllegiance': 'HOME',
#    'scheduleStatus': 'NORMAL',
#    'originalStartTime': None,
#    'delayedOrPostponedReason': None,
#    'playedStatus': 'COMPLETED',
#    'attendance': None,
#    'officials': [],
#    'broadcasters': [],
#    'weather': None},
#   'score': {'currentQuarter': None,
#    'currentQuarterSecondsRemaining': None,
#    'currentIntermission': None,
#    'awayScoreTotal': 91,
#    'homeScoreTotal': 119,
#    'quarters': [{'quarterNumber': 1, 'awayScore': 16, 'homeScore': 30},
#     {'quarterNumber': 2, 'awayScore': 33, 'homeScore': 35},
#     {'quarterNumber': 3, 'awayScore': 30, 'homeScore': 27},
#     {'quarterNumber': 4, 'awayScore': 12, 'homeScore': 27}]}},
#  {'schedule': {'id': 47603,
#    'startTime': '2018-10-21T02:00:00.000Z',
#    'endedTime': None,
#    'awayTeam': {'id': 106, 'abbreviation': 'SAS'},
#    'homeTeam': {'id': 97, 'abbreviation': 'POR'},
#    'venue': {'id': 91, 'name': 'Moda Center'},
#    'venueAllegiance': 'HOME',
#    'scheduleStatus': 'NORMAL',
#    'originalStartTime': None,
#    'delayedOrPostponedReason': None,
#    'playedStatus': 'COMPLETED',
#    'attendance': None,
#    'officials': [],
#    'broadcasters': [],
#    'weather': None},
#   'score': {'currentQuarter': None,
#    'currentQuarterSecondsRemaining': None,
#    'currentIntermission': None,
#    'awayScoreTotal': 108,
#    'homeScoreTotal': 121,
#    'quarters': [{'quarterNumber': 1, 'awayScore': 22, 'homeScore': 22},
#     {'quarterNumber': 2, 'awayScore': 28, 'homeScore': 37},
#     {'quarterNumber': 3, 'awayScore': 32, 'homeScore': 38},
#     {'quarterNumber': 4, 'awayScore': 26, 'homeScore': 24}]}},
#  {'schedule': {'id': 47604,
#    'startTime': '2018-10-21T02:30:00.000Z',
#    'endedTime': None,
#    'awayTeam': {'id': 109, 'abbreviation': 'HOU'},
#    'homeTeam': {'id': 105, 'abbreviation': 'LAL'},
#    'venue': {'id': 25, 'name': 'Staples Center'},
#    'venueAllegiance': 'HOME',
#    'scheduleStatus': 'NORMAL',
#    'originalStartTime': None,
#    'delayedOrPostponedReason': None,
#    'playedStatus': 'COMPLETED',
#    'attendance': None,
#    'officials': [],
#    'broadcasters': [],
#    'weather': None},
#   'score': {'currentQuarter': None,
#    'currentQuarterSecondsRemaining': None,
#    'currentIntermission': None,
#    'awayScoreTotal': 124,
#    'homeScoreTotal': 115,
#    'quarters': [{'quarterNumber': 1, 'awayScore': 31, 'homeScore': 28},
#     {'quarterNumber': 2, 'awayScore': 35, 'homeScore': 34},
#     {'quarterNumber': 3, 'awayScore': 32, 'homeScore': 35},
#     {'quarterNumber': 4, 'awayScore': 26, 'homeScore': 18}]}},
#  {'schedule': {'id': 47605,
#    'startTime': '2018-10-21T22:00:00.000Z',
#    'endedTime': None,
#    'awayTeam': {'id': 91, 'abbreviation': 'ATL'},
#    'homeTeam': {'id': 86, 'abbreviation': 'CLE'},
#    'venue': {'id': 80, 'name': 'Quicken Loans Arena'},
#    'venueAllegiance': 'HOME',
#    'scheduleStatus': 'NORMAL',
#    'originalStartTime': None,
#    'delayedOrPostponedReason': None,
#    'playedStatus': 'COMPLETED',
#    'attendance': None,
#    'officials': [],
#    'broadcasters': [],
#    'weather': None},
#   'score': {'currentQuarter': None,
#    'currentQuarterSecondsRemaining': None,
#    'currentIntermission': None,
#    'awayScoreTotal': 133,
#    'homeScoreTotal': 111,
#    'quarters': [{'quarterNumber': 1, 'awayScore': 24, 'homeScore': 34},
#     {'quarterNumber': 2, 'awayScore': 40, 'homeScore': 26},
#     {'quarterNumber': 3, 'awayScore': 28, 'homeScore': 26},
#     {'quarterNumber': 4, 'awayScore': 41, 'homeScore': 25}]}},
#  {'schedule': {'id': 47606,
#    'startTime': '2018-10-21T23:00:00.000Z',
#    'endedTime': None,
#    'awayTeam': {'id': 103, 'abbreviation': 'SAC'},
#    'homeTeam': {'id': 96, 'abbreviation': 'OKL'},
#    'venue': {'id': 90, 'name': 'Chesapeake Energy Arena'},
#    'venueAllegiance': 'HOME',
#    'scheduleStatus': 'NORMAL',
#    'originalStartTime': None,
#    'delayedOrPostponedReason': None,
#    'playedStatus': 'COMPLETED',
#    'attendance': None,
#    'officials': [],
#    'broadcasters': [],
#    'weather': None},
#   'score': {'currentQuarter': None,
#    'currentQuarterSecondsRemaining': None,
#    'currentIntermission': None,
#    'awayScoreTotal': 131,
#    'homeScoreTotal': 120,
#    'quarters': [{'quarterNumber': 1, 'awayScore': 34, 'homeScore': 32},
#     {'quarterNumber': 2, 'awayScore': 34, 'homeScore': 24},
#     {'quarterNumber': 3, 'awayScore': 29, 'homeScore': 34},
#     {'quarterNumber': 4, 'awayScore': 34, 'homeScore': 30}]}},
#  {'schedule': {'id': 47607,
#    'startTime': '2018-10-22T00:00:00.000Z',
#    'endedTime': None,
#    'awayTeam': {'id': 101, 'abbreviation': 'GSW'},
#    'homeTeam': {'id': 99, 'abbreviation': 'DEN'},
#    'venue': {'id': 19, 'name': 'Pepsi Center'},
#    'venueAllegiance': 'HOME',
#    'scheduleStatus': 'NORMAL',
#    'originalStartTime': None,
#    'delayedOrPostponedReason': None,
#    'playedStatus': 'COMPLETED',
#    'attendance': None,
#    'officials': [],
#    'broadcasters': [],
#    'weather': None},
#   'score': {'currentQuarter': None,
#    'currentQuarterSecondsRemaining': None,
#    'currentIntermission': None,
#    'awayScoreTotal': 98,
#    'homeScoreTotal': 100,
#    'quarters': [{'quarterNumber': 1, 'awayScore': 25, 'homeScore': 17},
#     {'quarterNumber': 2, 'awayScore': 24, 'homeScore': 30},
#     {'quarterNumber': 3, 'awayScore': 21, 'homeScore': 33},
#     {'quarterNumber': 4, 'awayScore': 28, 'homeScore': 20}]}},
#  {'schedule': {'id': 47608,
#    'startTime': '2018-10-22T01:00:00.000Z',
#    'endedTime': None,
#    'awayTeam': {'id': 109, 'abbreviation': 'HOU'},
#    'homeTeam': {'id': 102, 'abbreviation': 'LAC'},
#    'venue': {'id': 25, 'name': 'Staples Center'},
#    'venueAllegiance': 'HOME',
#    'scheduleStatus': 'NORMAL',
#    'originalStartTime': None,
#    'delayedOrPostponedReason': None,
#    'playedStatus': 'COMPLETED',
#    'attendance': None,
#    'officials': [],
#    'broadcasters': [],
#    'weather': None},
#   'score': {'currentQuarter': None,
#    'currentQuarterSecondsRemaining': None,
#    'currentIntermission': None,
#    'awayScoreTotal': 112,
#    'homeScoreTotal': 115,
#    'quarters': [{'quarterNumber': 1, 'awayScore': 24, 'homeScore': 29},
#     {'quarterNumber': 2, 'awayScore': 29, 'homeScore': 25},
#     {'quarterNumber': 3, 'awayScore': 31, 'homeScore': 39},
#     {'quarterNumber': 4, 'awayScore': 28, 'homeScore': 22}]}},
#  {'schedule': {'id': 47609,
#    'startTime': '2018-10-22T23:30:00.000Z',
#    'endedTime': None,
#    'awayTeam': {'id': 95, 'abbreviation': 'ORL'},
#    'homeTeam': {'id': 82, 'abbreviation': 'BOS'},
#    'venue': {'id': 27, 'name': 'TD Garden'},
#    'venueAllegiance': 'HOME',
#    'scheduleStatus': 'NORMAL',
#    'originalStartTime': None,
#    'delayedOrPostponedReason': None,
#    'playedStatus': 'COMPLETED',
#    'attendance': None,
#    'officials': [],
#    'broadcasters': [],
#    'weather': None},
#   'score': {'currentQuarter': None,
#    'currentQuarterSecondsRemaining': None,
#    'currentIntermission': None,
#    'awayScoreTotal': 93,
#    'homeScoreTotal': 90,
#    'quarters': [{'quarterNumber': 1, 'awayScore': 28, 'homeScore': 19},
#     {'quarterNumber': 2, 'awayScore': 20, 'homeScore': 26},
#     {'quarterNumber': 3, 'awayScore': 27, 'homeScore': 25},
#     {'quarterNumber': 4, 'awayScore': 18, 'homeScore': 20}]}},
#  {'schedule': {'id': 47610,
#    'startTime': '2018-10-22T23:30:00.000Z',
#    'endedTime': None,
#    'awayTeam': {'id': 93, 'abbreviation': 'CHA'},
#    'homeTeam': {'id': 81, 'abbreviation': 'TOR'},
#    'venue': {'id': 1, 'name': 'Scotiabank Arena'},
#    'venueAllegiance': 'HOME',
#    'scheduleStatus': 'NORMAL',
#    'originalStartTime': None,
#    'delayedOrPostponedReason': None,
#    'playedStatus': 'COMPLETED',
#    'attendance': None,
#    'officials': [],
#    'broadcasters': [],
#    'weather': None},
#   'score': {'currentQuarter': None,
#    'currentQuarterSecondsRemaining': None,
#    'currentIntermission': None,
#    'awayScoreTotal': 106,
#    'homeScoreTotal': 127,
#    'quarters': [{'quarterNumber': 1, 'awayScore': 22, 'homeScore': 31},
#     {'quarterNumber': 2, 'awayScore': 25, 'homeScore': 31},
#     {'quarterNumber': 3, 'awayScore': 32, 'homeScore': 35},
#     {'quarterNumber': 4, 'awayScore': 27, 'homeScore': 30}]}},
#  {'schedule': {'id': 47611,
#    'startTime': '2018-10-23T00:00:00.000Z',
#    'endedTime': None,
#    'awayTeam': {'id': 83, 'abbreviation': 'NYK'},
#    'homeTeam': {'id': 90, 'abbreviation': 'MIL'},
#    'venue': {'id': 152, 'name': 'Fiserv Forum'},
#    'venueAllegiance': 'HOME',
#    'scheduleStatus': 'NORMAL',
#    'originalStartTime': None,
#    'delayedOrPostponedReason': None,
#    'playedStatus': 'COMPLETED',
#    'attendance': None,
#    'officials': [],
#    'broadcasters': [],
#    'weather': None},
#   'score': {'currentQuarter': None,
#    'currentQuarterSecondsRemaining': None,
#    'currentIntermission': None,
#    'awayScoreTotal': 113,
#    'homeScoreTotal': 124,
#    'quarters': [{'quarterNumber': 1, 'awayScore': 29, 'homeScore': 33},
#     {'quarterNumber': 2, 'awayScore': 23, 'homeScore': 38},
#     {'quarterNumber': 3, 'awayScore': 35, 'homeScore': 17},
#     {'quarterNumber': 4, 'awayScore': 26, 'homeScore': 36}]}},
#  {'schedule': {'id': 47612,
#    'startTime': '2018-10-23T00:00:00.000Z',
#    'endedTime': None,
#    'awayTeam': {'id': 87, 'abbreviation': 'IND'},
#    'homeTeam': {'id': 100, 'abbreviation': 'MIN'},
#    'venue': {'id': 94, 'name': 'Target Center'},
#    'venueAllegiance': 'HOME',
#    'scheduleStatus': 'NORMAL',
#    'originalStartTime': None,
#    'delayedOrPostponedReason': None,
#    'playedStatus': 'COMPLETED',
#    'attendance': None,
#    'officials': [],
#    'broadcasters': [],
#    'weather': None},
#   'score': {'currentQuarter': None,
#    'currentQuarterSecondsRemaining': None,
#    'currentIntermission': None,
#    'awayScoreTotal': 91,
#    'homeScoreTotal': 101,
#    'quarters': [{'quarterNumber': 1, 'awayScore': 28, 'homeScore': 25},
#     {'quarterNumber': 2, 'awayScore': 21, 'homeScore': 25},
#     {'quarterNumber': 3, 'awayScore': 24, 'homeScore': 22},
#     {'quarterNumber': 4, 'awayScore': 18, 'homeScore': 29}]}},
#  {'schedule': {'id': 47613,
#    'startTime': '2018-10-23T00:30:00.000Z',
#    'endedTime': None,
#    'awayTeam': {'id': 89, 'abbreviation': 'CHI'},
#    'homeTeam': {'id': 108, 'abbreviation': 'DAL'},
#    'venue': {'id': 2, 'name': 'American Airlines Center'},
#    'venueAllegiance': 'HOME',
#    'scheduleStatus': 'NORMAL',
#    'originalStartTime': None,
#    'delayedOrPostponedReason': None,
#    'playedStatus': 'COMPLETED',
#    'attendance': None,
#    'officials': [],
#    'broadcasters': [],
#    'weather': None},
#   'score': {'currentQuarter': None,
#    'currentQuarterSecondsRemaining': None,
#    'currentIntermission': None,
#    'awayScoreTotal': 109,
#    'homeScoreTotal': 115,
#    'quarters': [{'quarterNumber': 1, 'awayScore': 28, 'homeScore': 31},
#     {'quarterNumber': 2, 'awayScore': 33, 'homeScore': 28},
#     {'quarterNumber': 3, 'awayScore': 23, 'homeScore': 29},
#     {'quarterNumber': 4, 'awayScore': 25, 'homeScore': 27}]}},
#  {'schedule': {'id': 47614,
#    'startTime': '2018-10-23T01:00:00.000Z',
#    'endedTime': None,
#    'awayTeam': {'id': 107, 'abbreviation': 'MEM'},
#    'homeTeam': {'id': 98, 'abbreviation': 'UTA'},
#    'venue': {'id': 92, 'name': 'Vivint Smart Home Arena'},
#    'venueAllegiance': 'HOME',
#    'scheduleStatus': 'NORMAL',
#    'originalStartTime': None,
#    'delayedOrPostponedReason': None,
#    'playedStatus': 'COMPLETED',
#    'attendance': None,
#    'officials': [],
#    'broadcasters': [],
#    'weather': None},
#   'score': {'currentQuarter': None,
#    'currentQuarterSecondsRemaining': None,
#    'currentIntermission': None,
#    'awayScoreTotal': 92,
#    'homeScoreTotal': 84,
#    'quarters': [{'quarterNumber': 1, 'awayScore': 19, 'homeScore': 22},
#     {'quarterNumber': 2, 'awayScore': 28, 'homeScore': 24},
#     {'quarterNumber': 3, 'awayScore': 23, 'homeScore': 17},
#     {'quarterNumber': 4, 'awayScore': 22, 'homeScore': 21}]}},
#  {'schedule': {'id': 47615,
#    'startTime': '2018-10-23T02:00:00.000Z',
#    'endedTime': None,
#    'awayTeam': {'id': 94, 'abbreviation': 'WAS'},
#    'homeTeam': {'id': 97, 'abbreviation': 'POR'},
#    'venue': {'id': 91, 'name': 'Moda Center'},
#    'venueAllegiance': 'HOME',
#    'scheduleStatus': 'NORMAL',
#    'originalStartTime': None,
#    'delayedOrPostponedReason': None,
#    'playedStatus': 'COMPLETED',
#    'attendance': None,
#    'officials': [],
#    'broadcasters': [],
#    'weather': None},
#   'score': {'currentQuarter': None,
#    'currentQuarterSecondsRemaining': None,
#    'currentIntermission': None,
#    'awayScoreTotal': 125,
#    'homeScoreTotal': 124,
#    'quarters': [{'quarterNumber': 1, 'awayScore': 28, 'homeScore': 32},
#     {'quarterNumber': 2, 'awayScore': 34, 'homeScore': 30},
#     {'quarterNumber': 3, 'awayScore': 16, 'homeScore': 15},
#     {'quarterNumber': 4, 'awayScore': 33, 'homeScore': 34},
#     {'quarterNumber': 5, 'awayScore': 14, 'homeScore': 13}]}},
#  {'schedule': {'id': 47616,
#    'startTime': '2018-10-23T02:30:00.000Z',
#    'endedTime': None,
#    'awayTeam': {'id': 104, 'abbreviation': 'PHX'},
#    'homeTeam': {'id': 101, 'abbreviation': 'GSW'},
#    'venue': {'id': 95, 'name': 'Oracle Arena'},
#    'venueAllegiance': 'HOME',
#    'scheduleStatus': 'NORMAL',
#    'originalStartTime': None,
#    'delayedOrPostponedReason': None,
#    'playedStatus': 'COMPLETED',
#    'attendance': None,
#    'officials': [],
#    'broadcasters': [],
#    'weather': None},
#   'score': {'currentQuarter': None,
#    'currentQuarterSecondsRemaining': None,
#    'currentIntermission': None,
#    'awayScoreTotal': 103,
#    'homeScoreTotal': 123,
#    'quarters': [{'quarterNumber': 1, 'awayScore': 23, 'homeScore': 32},
#     {'quarterNumber': 2, 'awayScore': 24, 'homeScore': 38},
#     {'quarterNumber': 3, 'awayScore': 34, 'homeScore': 36},
#     {'quarterNumber': 4, 'awayScore': 22, 'homeScore': 17}]}},
#  {'schedule': {'id': 47617,
#    'startTime': '2018-10-23T02:30:00.000Z',
#    'endedTime': None,
#    'awayTeam': {'id': 106, 'abbreviation': 'SAS'},
#    'homeTeam': {'id': 105, 'abbreviation': 'LAL'},
#    'venue': {'id': 25, 'name': 'Staples Center'},
#    'venueAllegiance': 'HOME',
#    'scheduleStatus': 'NORMAL',
#    'originalStartTime': None,
#    'delayedOrPostponedReason': None,
#    'playedStatus': 'COMPLETED',
#    'attendance': None,
#    'officials': [],
#    'broadcasters': [],
#    'weather': None},
#   'score': {'currentQuarter': None,
#    'currentQuarterSecondsRemaining': None,
#    'currentIntermission': None,
#    'awayScoreTotal': 143,
#    'homeScoreTotal': 142,
#    'quarters': [{'quarterNumber': 1, 'awayScore': 40, 'homeScore': 26},
#     {'quarterNumber': 2, 'awayScore': 25, 'homeScore': 34},
#     {'quarterNumber': 3, 'awayScore': 34, 'homeScore': 36},
#     {'quarterNumber': 4, 'awayScore': 29, 'homeScore': 32},
#     {'quarterNumber': 5, 'awayScore': 15, 'homeScore': 14}]}},
#  {'schedule': {'id': 47618,
#    'startTime': '2018-10-23T23:00:00.000Z',
#    'endedTime': None,
#    'awayTeam': {'id': 85, 'abbreviation': 'PHI'},
#    'homeTeam': {'id': 88, 'abbreviation': 'DET'},
#    'venue': {'id': 145, 'name': 'Little Caesars Arena'},
#    'venueAllegiance': 'HOME',
#    'scheduleStatus': 'NORMAL',
#    'originalStartTime': None,
#    'delayedOrPostponedReason': None,
#    'playedStatus': 'COMPLETED',
#    'attendance': None,
#    'officials': [],
#    'broadcasters': [],
#    'weather': None},
#   'score': {'currentQuarter': None,
#    'currentQuarterSecondsRemaining': None,
#    'currentIntermission': None,
#    'awayScoreTotal': 132,
#    'homeScoreTotal': 133,
#    'quarters': [{'quarterNumber': 1, 'awayScore': 28, 'homeScore': 27},
#     {'quarterNumber': 2, 'awayScore': 36, 'homeScore': 34},
#     {'quarterNumber': 3, 'awayScore': 30, 'homeScore': 26},
#     {'quarterNumber': 4, 'awayScore': 26, 'homeScore': 33},
#     {'quarterNumber': 5, 'awayScore': 12, 'homeScore': 13}]}},
#  {'schedule': {'id': 47619,
#    'startTime': '2018-10-24T00:00:00.000Z',
#    'endedTime': None,
#    'awayTeam': {'id': 102, 'abbreviation': 'LAC'},
#    'homeTeam': {'id': 110, 'abbreviation': 'NOP'},
#    'venue': {'id': 103, 'name': 'Smoothie King Center'},
#    'venueAllegiance': 'HOME',
#    'scheduleStatus': 'NORMAL',
#    'originalStartTime': None,
#    'delayedOrPostponedReason': None,
#    'playedStatus': 'COMPLETED',
#    'attendance': None,
#    'officials': [],
#    'broadcasters': [],
#    'weather': None},
#   'score': {'currentQuarter': None,
#    'currentQuarterSecondsRemaining': None,
#    'currentIntermission': None,
#    'awayScoreTotal': 109,
#    'homeScoreTotal': 116,
#    'quarters': [{'quarterNumber': 1, 'awayScore': 26, 'homeScore': 27},
#     {'quarterNumber': 2, 'awayScore': 36, 'homeScore': 32},
#     {'quarterNumber': 3, 'awayScore': 22, 'homeScore': 32},
#     {'quarterNumber': 4, 'awayScore': 25, 'homeScore': 25}]}},
#  {'schedule': {'id': 47620,
#    'startTime': '2018-10-24T01:00:00.000Z',
#    'endedTime': None,
#    'awayTeam': {'id': 103, 'abbreviation': 'SAC'},
#    'homeTeam': {'id': 99, 'abbreviation': 'DEN'},
#    'venue': {'id': 19, 'name': 'Pepsi Center'},
#    'venueAllegiance': 'HOME',
#    'scheduleStatus': 'NORMAL',
#    'originalStartTime': None,
#    'delayedOrPostponedReason': None,
#    'playedStatus': 'COMPLETED',
#    'attendance': None,
#    'officials': [],
#    'broadcasters': [],
#    'weather': None},
#   'score': {'currentQuarter': None,
#    'currentQuarterSecondsRemaining': None,
#    'currentIntermission': None,
#    'awayScoreTotal': 112,
#    'homeScoreTotal': 126,
#    'quarters': [{'quarterNumber': 1, 'awayScore': 26, 'homeScore': 33},
#     {'quarterNumber': 2, 'awayScore': 29, 'homeScore': 35},
#     {'quarterNumber': 3, 'awayScore': 26, 'homeScore': 37},
#     {'quarterNumber': 4, 'awayScore': 31, 'homeScore': 21}]}},
#  {'schedule': {'id': 47621,
#    'startTime': '2018-10-24T23:00:00.000Z',
#    'endedTime': None,
#    'awayTeam': {'id': 108, 'abbreviation': 'DAL'},
#    'homeTeam': {'id': 91, 'abbreviation': 'ATL'},
#    'venue': {'id': 20, 'name': 'State Farm Arena'},
#    'venueAllegiance': 'HOME',
#    'scheduleStatus': 'NORMAL',
#    'originalStartTime': None,
#    'delayedOrPostponedReason': None,
#    'playedStatus': 'COMPLETED',
#    'attendance': None,
#    'officials': [],
#    'broadcasters': [],
#    'weather': None},
#   'score': {'currentQuarter': None,
#    'currentQuarterSecondsRemaining': None,
#    'currentIntermission': None,
#    'awayScoreTotal': 104,
#    'homeScoreTotal': 111,
#    'quarters': [{'quarterNumber': 1, 'awayScore': 42, 'homeScore': 22},
#     {'quarterNumber': 2, 'awayScore': 16, 'homeScore': 26},
#     {'quarterNumber': 3, 'awayScore': 29, 'homeScore': 32},
#     {'quarterNumber': 4, 'awayScore': 17, 'homeScore': 31}]}},
#  {'schedule': {'id': 47622,
#    'startTime': '2018-10-24T23:00:00.000Z',
#    'endedTime': None,
#    'awayTeam': {'id': 84, 'abbreviation': 'BRO'},
#    'homeTeam': {'id': 86, 'abbreviation': 'CLE'},
#    'venue': {'id': 80, 'name': 'Quicken Loans Arena'},
#    'venueAllegiance': 'HOME',
#    'scheduleStatus': 'NORMAL',
#    'originalStartTime': None,
#    'delayedOrPostponedReason': None,
#    'playedStatus': 'COMPLETED',
# ...
#    'weather': None},
#   'score': {'currentQuarter': None,
#    'currentQuarterSecondsRemaining': None,
#    'currentIntermission': None,
#    'awayScoreTotal': 127,
#    'homeScoreTotal': 104,
#    'quarters': [{'quarterNumber': 1, 'awayScore': 29, 'homeScore': 31},
#     {'quarterNumber': 2, 'awayScore': 35, 'homeScore': 30},
#     {'quarterNumber': 3, 'awayScore': 29, 'homeScore': 19},
#     {'quarterNumber': 4, 'awayScore': 34, 'homeScore': 24}]}},
#  {'schedule': {'id': 48553,
#    'startTime': '2019-03-09T03:30:00.000Z',
#    'endedTime': None,
#    'awayTeam': {'id': 99, 'abbreviation': 'DEN'},
#    'homeTeam': {'id': 101, 'abbreviation': 'GSW'},
#    'venue': {'id': 95, 'name': 'Oracle Arena'},
#    'venueAllegiance': 'HOME',
#    'scheduleStatus': 'NORMAL',
#    'originalStartTime': None,
#    'delayedOrPostponedReason': None,
#    'playedStatus': 'COMPLETED',
#    'attendance': None,
#    'officials': [],
#    'broadcasters': [],
#    'weather': None},
#   'score': {'currentQuarter': None,
#    'currentQuarterSecondsRemaining': None,
#    'currentIntermission': None,
#    'awayScoreTotal': 105,
#    'homeScoreTotal': 122,
#    'quarters': [{'quarterNumber': 1, 'awayScore': 20, 'homeScore': 30},
#     {'quarterNumber': 2, 'awayScore': 30, 'homeScore': 37},
#     {'quarterNumber': 3, 'awayScore': 25, 'homeScore': 23},
#     {'quarterNumber': 4, 'awayScore': 30, 'homeScore': 32}]}},
#  {'schedule': {'id': 48554,
#    'startTime': '2019-03-09T03:30:00.000Z',
#    'endedTime': None,
#    'awayTeam': {'id': 96, 'abbreviation': 'OKL'},
#    'homeTeam': {'id': 102, 'abbreviation': 'LAC'},
#    'venue': {'id': 25, 'name': 'Staples Center'},
#    'venueAllegiance': 'HOME',
#    'scheduleStatus': 'NORMAL',
#    'originalStartTime': None,
#    'delayedOrPostponedReason': None,
#    'playedStatus': 'COMPLETED',
#    'attendance': None,
#    'officials': [],
#    'broadcasters': [],
#    'weather': None},
#   'score': {'currentQuarter': None,
#    'currentQuarterSecondsRemaining': None,
#    'currentIntermission': None,
#    'awayScoreTotal': 110,
#    'homeScoreTotal': 118,
#    'quarters': [{'quarterNumber': 1, 'awayScore': 32, 'homeScore': 36},
#     {'quarterNumber': 2, 'awayScore': 24, 'homeScore': 32},
#     {'quarterNumber': 3, 'awayScore': 28, 'homeScore': 20},
#     {'quarterNumber': 4, 'awayScore': 26, 'homeScore': 30}]}},
#  {'schedule': {'id': 48555,
#    'startTime': '2019-03-09T17:00:00.000Z',
#    'endedTime': None,
#    'awayTeam': {'id': 103, 'abbreviation': 'SAC'},
#    'homeTeam': {'id': 83, 'abbreviation': 'NYK'},
#    'venue': {'id': 12, 'name': 'Madison Square Garden'},
#    'venueAllegiance': 'HOME',
#    'scheduleStatus': 'NORMAL',
#    'originalStartTime': None,
#    'delayedOrPostponedReason': None,
#    'playedStatus': 'COMPLETED',
#    'attendance': None,
#    'officials': [],
#    'broadcasters': [],
#    'weather': None},
#   'score': {'currentQuarter': None,
#    'currentQuarterSecondsRemaining': None,
#    'currentIntermission': None,
#    'awayScoreTotal': 102,
#    'homeScoreTotal': 94,
#    'quarters': [{'quarterNumber': 1, 'awayScore': 23, 'homeScore': 30},
#     {'quarterNumber': 2, 'awayScore': 25, 'homeScore': 16},
#     {'quarterNumber': 3, 'awayScore': 32, 'homeScore': 22},
#     {'quarterNumber': 4, 'awayScore': 22, 'homeScore': 26}]}},
#  {'schedule': {'id': 48556,
#    'startTime': '2019-03-10T00:00:00.000Z',
#    'endedTime': None,
#    'awayTeam': {'id': 84, 'abbreviation': 'BRO'},
#    'homeTeam': {'id': 91, 'abbreviation': 'ATL'},
#    'venue': {'id': 20, 'name': 'State Farm Arena'},
#    'venueAllegiance': 'HOME',
#    'scheduleStatus': 'NORMAL',
#    'originalStartTime': None,
#    'delayedOrPostponedReason': None,
#    'playedStatus': 'COMPLETED',
#    'attendance': None,
#    'officials': [],
#    'broadcasters': [],
#    'weather': None},
#   'score': {'currentQuarter': None,
#    'currentQuarterSecondsRemaining': None,
#    'currentIntermission': None,
#    'awayScoreTotal': 114,
#    'homeScoreTotal': 112,
#    'quarters': [{'quarterNumber': 1, 'awayScore': 26, 'homeScore': 23},
#     {'quarterNumber': 2, 'awayScore': 30, 'homeScore': 24},
#     {'quarterNumber': 3, 'awayScore': 27, 'homeScore': 30},
#     {'quarterNumber': 4, 'awayScore': 31, 'homeScore': 35}]}},
#  {'schedule': {'id': 48557,
#    'startTime': '2019-03-10T01:00:00.000Z',
#    'endedTime': None,
#    'awayTeam': {'id': 94, 'abbreviation': 'WAS'},
#    'homeTeam': {'id': 100, 'abbreviation': 'MIN'},
#    'venue': {'id': 94, 'name': 'Target Center'},
#    'venueAllegiance': 'HOME',
#    'scheduleStatus': 'NORMAL',
#    'originalStartTime': None,
#    'delayedOrPostponedReason': None,
#    'playedStatus': 'COMPLETED',
#    'attendance': None,
#    'officials': [],
#    'broadcasters': [],
#    'weather': None},
#   'score': {'currentQuarter': None,
#    'currentQuarterSecondsRemaining': None,
#    'currentIntermission': None,
#    'awayScoreTotal': 130,
#    'homeScoreTotal': 135,
#    'quarters': [{'quarterNumber': 1, 'awayScore': 39, 'homeScore': 28},
#     {'quarterNumber': 2, 'awayScore': 32, 'homeScore': 32},
#     {'quarterNumber': 3, 'awayScore': 28, 'homeScore': 35},
#     {'quarterNumber': 4, 'awayScore': 22, 'homeScore': 26},
#     {'quarterNumber': 5, 'awayScore': 9, 'homeScore': 14}]}},
#  {'schedule': {'id': 48558,
#    'startTime': '2019-03-10T01:30:00.000Z',
#    'endedTime': None,
#    'awayTeam': {'id': 82, 'abbreviation': 'BOS'},
#    'homeTeam': {'id': 105, 'abbreviation': 'LAL'},
#    'venue': {'id': 25, 'name': 'Staples Center'},
#    'venueAllegiance': 'HOME',
#    'scheduleStatus': 'NORMAL',
#    'originalStartTime': None,
#    'delayedOrPostponedReason': None,
#    'playedStatus': 'COMPLETED',
#    'attendance': None,
#    'officials': [],
#    'broadcasters': [],
#    'weather': None},
#   'score': {'currentQuarter': None,
#    'currentQuarterSecondsRemaining': None,
#    'currentIntermission': None,
#    'awayScoreTotal': 120,
#    'homeScoreTotal': 107,
#    'quarters': [{'quarterNumber': 1, 'awayScore': 25, 'homeScore': 24},
#     {'quarterNumber': 2, 'awayScore': 32, 'homeScore': 23},
#     {'quarterNumber': 3, 'awayScore': 36, 'homeScore': 29},
#     {'quarterNumber': 4, 'awayScore': 27, 'homeScore': 31}]}},
#  {'schedule': {'id': 48559,
#    'startTime': '2019-03-10T02:00:00.000Z',
#    'endedTime': None,
#    'awayTeam': {'id': 93, 'abbreviation': 'CHA'},
#    'homeTeam': {'id': 90, 'abbreviation': 'MIL'},
#    'venue': {'id': 152, 'name': 'Fiserv Forum'},
#    'venueAllegiance': 'HOME',
#    'scheduleStatus': 'NORMAL',
#    'originalStartTime': None,
#    'delayedOrPostponedReason': None,
#    'playedStatus': 'COMPLETED',
#    'attendance': None,
#    'officials': [],
#    'broadcasters': [],
#    'weather': None},
#   'score': {'currentQuarter': None,
#    'currentQuarterSecondsRemaining': None,
#    'currentIntermission': None,
#    'awayScoreTotal': 114,
#    'homeScoreTotal': 131,
#    'quarters': [{'quarterNumber': 1, 'awayScore': 32, 'homeScore': 24},
#     {'quarterNumber': 2, 'awayScore': 27, 'homeScore': 31},
#     {'quarterNumber': 3, 'awayScore': 28, 'homeScore': 39},
#     {'quarterNumber': 4, 'awayScore': 27, 'homeScore': 37}]}},
#  {'schedule': {'id': 48560,
#    'startTime': '2019-03-10T03:00:00.000Z',
#    'endedTime': None,
#    'awayTeam': {'id': 104, 'abbreviation': 'PHX'},
#    'homeTeam': {'id': 97, 'abbreviation': 'POR'},
#    'venue': {'id': 91, 'name': 'Moda Center'},
#    'venueAllegiance': 'HOME',
#    'scheduleStatus': 'NORMAL',
#    'originalStartTime': None,
#    'delayedOrPostponedReason': None,
#    'playedStatus': 'COMPLETED',
#    'attendance': None,
#    'officials': [],
#    'broadcasters': [],
#    'weather': None},
#   'score': {'currentQuarter': None,
#    'currentQuarterSecondsRemaining': None,
#    'currentIntermission': None,
#    'awayScoreTotal': 120,
#    'homeScoreTotal': 127,
#    'quarters': [{'quarterNumber': 1, 'awayScore': 23, 'homeScore': 24},
#     {'quarterNumber': 2, 'awayScore': 24, 'homeScore': 42},
#     {'quarterNumber': 3, 'awayScore': 30, 'homeScore': 36},
#     {'quarterNumber': 4, 'awayScore': 43, 'homeScore': 25}]}},
#  {'schedule': {'id': 48561,
#    'startTime': '2019-03-10T16:00:00.000Z',
#    'endedTime': None,
#    'awayTeam': {'id': 89, 'abbreviation': 'CHI'},
#    'homeTeam': {'id': 88, 'abbreviation': 'DET'},
#    'venue': {'id': 145, 'name': 'Little Caesars Arena'},
#    'venueAllegiance': 'HOME',
#    'scheduleStatus': 'NORMAL',
#    'originalStartTime': None,
#    'delayedOrPostponedReason': None,
#    'playedStatus': 'COMPLETED',
#    'attendance': None,
#    'officials': [],
#    'broadcasters': [],
#    'weather': None},
#   'score': {'currentQuarter': None,
#    'currentQuarterSecondsRemaining': None,
#    'currentIntermission': None,
#    'awayScoreTotal': 108,
#    'homeScoreTotal': 131,
#    'quarters': [{'quarterNumber': 1, 'awayScore': 32, 'homeScore': 31},
#     {'quarterNumber': 2, 'awayScore': 23, 'homeScore': 30},
#     {'quarterNumber': 3, 'awayScore': 25, 'homeScore': 42},
#     {'quarterNumber': 4, 'awayScore': 28, 'homeScore': 28}]}},
#  {'schedule': {'id': 48562,
#    'startTime': '2019-03-10T19:30:00.000Z',
#    'endedTime': None,
#    'awayTeam': {'id': 81, 'abbreviation': 'TOR'},
#    'homeTeam': {'id': 92, 'abbreviation': 'MIA'},
#    'venue': {'id': 86, 'name': 'American Airlines Arena'},
#    'venueAllegiance': 'HOME',
#    'scheduleStatus': 'NORMAL',
#    'originalStartTime': None,
#    'delayedOrPostponedReason': None,
#    'playedStatus': 'COMPLETED',
#    'attendance': None,
#    'officials': [],
#    'broadcasters': [],
#    'weather': None},
#   'score': {'currentQuarter': None,
#    'currentQuarterSecondsRemaining': None,
#    'currentIntermission': None,
#    'awayScoreTotal': 125,
#    'homeScoreTotal': 104,
#    'quarters': [{'quarterNumber': 1, 'awayScore': 32, 'homeScore': 27},
#     {'quarterNumber': 2, 'awayScore': 36, 'homeScore': 27},
#     {'quarterNumber': 3, 'awayScore': 23, 'homeScore': 25},
#     {'quarterNumber': 4, 'awayScore': 34, 'homeScore': 25}]}},
#  {'schedule': {'id': 48563,
#    'startTime': '2019-03-10T19:30:00.000Z',
#    'endedTime': None,
#    'awayTeam': {'id': 87, 'abbreviation': 'IND'},
#    'homeTeam': {'id': 85, 'abbreviation': 'PHI'},
#    'venue': {'id': 29, 'name': 'Wells Fargo Center'},
#    'venueAllegiance': 'HOME',
#    'scheduleStatus': 'NORMAL',
#    'originalStartTime': None,
#    'delayedOrPostponedReason': None,
#    'playedStatus': 'COMPLETED',
#    'attendance': None,
#    'officials': [],
#    'broadcasters': [],
#    'weather': None},
#   'score': {'currentQuarter': None,
#    'currentQuarterSecondsRemaining': None,
#    'currentIntermission': None,
#    'awayScoreTotal': 89,
#    'homeScoreTotal': 106,
#    'quarters': [{'quarterNumber': 1, 'awayScore': 25, 'homeScore': 26},
#     {'quarterNumber': 2, 'awayScore': 34, 'homeScore': 25},
#     {'quarterNumber': 3, 'awayScore': 11, 'homeScore': 21},
#     {'quarterNumber': 4, 'awayScore': 19, 'homeScore': 34}]}},
#  {'schedule': {'id': 48564,
#    'startTime': '2019-03-10T22:00:00.000Z',
#    'endedTime': None,
#    'awayTeam': {'id': 110, 'abbreviation': 'NOP'},
#    'homeTeam': {'id': 91, 'abbreviation': 'ATL'},
#    'venue': {'id': 20, 'name': 'State Farm Arena'},
#    'venueAllegiance': 'HOME',
#    'scheduleStatus': 'NORMAL',
#    'originalStartTime': None,
#    'delayedOrPostponedReason': None,
#    'playedStatus': 'COMPLETED',
#    'attendance': None,
#    'officials': [],
#    'broadcasters': [],
#    'weather': None},
#   'score': {'currentQuarter': None,
#    'currentQuarterSecondsRemaining': None,
#    'currentIntermission': None,
#    'awayScoreTotal': 116,
#    'homeScoreTotal': 128,
#    'quarters': [{'quarterNumber': 1, 'awayScore': 33, 'homeScore': 26},
#     {'quarterNumber': 2, 'awayScore': 33, 'homeScore': 39},
#     {'quarterNumber': 3, 'awayScore': 20, 'homeScore': 29},
#     {'quarterNumber': 4, 'awayScore': 30, 'homeScore': 34}]}},
#  {'schedule': {'id': 48565,
#    'startTime': '2019-03-10T22:00:00.000Z',
#    'endedTime': None,
#    'awayTeam': {'id': 95, 'abbreviation': 'ORL'},
#    'homeTeam': {'id': 107, 'abbreviation': 'MEM'},
#    'venue': {'id': 100, 'name': 'FedEx Forum'},
#    'venueAllegiance': 'HOME',
#    'scheduleStatus': 'NORMAL',
#    'originalStartTime': None,
#    'delayedOrPostponedReason': None,
#    'playedStatus': 'COMPLETED',
#    'attendance': None,
#    'officials': [],
#    'broadcasters': [],
#    'weather': None},
#   'score': {'currentQuarter': None,
#    'currentQuarterSecondsRemaining': None,
#    'currentIntermission': None,
#    'awayScoreTotal': 97,
#    'homeScoreTotal': 105,
#    'quarters': [{'quarterNumber': 1, 'awayScore': 17, 'homeScore': 26},
#     {'quarterNumber': 2, 'awayScore': 31, 'homeScore': 23},
#     {'quarterNumber': 3, 'awayScore': 24, 'homeScore': 26},
#     {'quarterNumber': 4, 'awayScore': 25, 'homeScore': 30}]}},
#  {'schedule': {'id': 48566,
#    'startTime': '2019-03-10T23:00:00.000Z',
#    'endedTime': None,
#    'awayTeam': {'id': 109, 'abbreviation': 'HOU'},
#    'homeTeam': {'id': 108, 'abbreviation': 'DAL'},
#    'venue': {'id': 2, 'name': 'American Airlines Center'},
#    'venueAllegiance': 'HOME',
#    'scheduleStatus': 'NORMAL',
#    'originalStartTime': None,
#    'delayedOrPostponedReason': None,
#    'playedStatus': 'COMPLETED',
#    'attendance': None,
#    'officials': [],
#    'broadcasters': [],
#    'weather': None},
#   'score': {'currentQuarter': None,
#    'currentQuarterSecondsRemaining': None,
#    'currentIntermission': None,
#    'awayScoreTotal': 94,
#    'homeScoreTotal': 93,
#    'quarters': [{'quarterNumber': 1, 'awayScore': 25, 'homeScore': 26},
#     {'quarterNumber': 2, 'awayScore': 33, 'homeScore': 28},
#     {'quarterNumber': 3, 'awayScore': 23, 'homeScore': 18},
#     {'quarterNumber': 4, 'awayScore': 13, 'homeScore': 21}]}},
#  {'schedule': {'id': 48567,
#    'startTime': '2019-03-11T00:00:00.000Z',
#    'endedTime': None,
#    'awayTeam': {'id': 83, 'abbreviation': 'NYK'},
#    'homeTeam': {'id': 100, 'abbreviation': 'MIN'},
#    'venue': {'id': 94, 'name': 'Target Center'},
#    'venueAllegiance': 'HOME',
#    'scheduleStatus': 'NORMAL',
#    'originalStartTime': None,
#    'delayedOrPostponedReason': None,
#    'playedStatus': 'COMPLETED',
#    'attendance': None,
#    'officials': [],
#    'broadcasters': [],
#    'weather': None},
#   'score': {'currentQuarter': None,
#    'currentQuarterSecondsRemaining': None,
#    'currentIntermission': None,
#    'awayScoreTotal': 92,
#    'homeScoreTotal': 103,
#    'quarters': [{'quarterNumber': 1, 'awayScore': 22, 'homeScore': 23},
#     {'quarterNumber': 2, 'awayScore': 23, 'homeScore': 32},
#     {'quarterNumber': 3, 'awayScore': 20, 'homeScore': 25},
#     {'quarterNumber': 4, 'awayScore': 27, 'homeScore': 23}]}},
#  {'schedule': {'id': 48568,
#    'startTime': '2019-03-11T00:00:00.000Z',
#    'endedTime': None,
#    'awayTeam': {'id': 90, 'abbreviation': 'MIL'},
#    'homeTeam': {'id': 106, 'abbreviation': 'SAS'},
#    'venue': {'id': 99, 'name': 'AT&T Center'},
#    'venueAllegiance': 'HOME',
#    'scheduleStatus': 'NORMAL',
#    'originalStartTime': None,
#    'delayedOrPostponedReason': None,
#    'playedStatus': 'COMPLETED',
#    'attendance': None,
#    'officials': [],
#    'broadcasters': [],
#    'weather': None},
#   'score': {'currentQuarter': None,
#    'currentQuarterSecondsRemaining': None,
#    'currentIntermission': None,
#    'awayScoreTotal': 114,
#    'homeScoreTotal': 121,
#    'quarters': [{'quarterNumber': 1, 'awayScore': 32, 'homeScore': 25},
#     {'quarterNumber': 2, 'awayScore': 28, 'homeScore': 29},
#     {'quarterNumber': 3, 'awayScore': 23, 'homeScore': 33},
#     {'quarterNumber': 4, 'awayScore': 31, 'homeScore': 34}]}},
#  {'schedule': {'id': 48569,
#    'startTime': '2019-03-11T00:30:00.000Z',
#    'endedTime': None,
#    'awayTeam': {'id': 104, 'abbreviation': 'PHX'},
#    'homeTeam': {'id': 101, 'abbreviation': 'GSW'},
#    'venue': {'id': 95, 'name': 'Oracle Arena'},
#    'venueAllegiance': 'HOME',
#    'scheduleStatus': 'NORMAL',
#    'originalStartTime': None,
#    'delayedOrPostponedReason': None,
#    'playedStatus': 'COMPLETED',
#    'attendance': None,
#    'officials': [],
#    'broadcasters': [],
#    'weather': None},
#   'score': {'currentQuarter': None,
#    'currentQuarterSecondsRemaining': None,
#    'currentIntermission': None,
#    'awayScoreTotal': 115,
#    'homeScoreTotal': 111,
#    'quarters': [{'quarterNumber': 1, 'awayScore': 16, 'homeScore': 29},
#     {'quarterNumber': 2, 'awayScore': 40, 'homeScore': 28},
#     {'quarterNumber': 3, 'awayScore': 23, 'homeScore': 23},
#     {'quarterNumber': 4, 'awayScore': 36, 'homeScore': 31}]}},
#  ...]

# %%
nbaDataSchedule = pd.concat([nbaData.schedule.apply(pd.Series), df.drop('schedule', axis=1)], axis=1)

# %%
nbaDataSchedule.head()
# Out:
#       id                 startTime endedTime  \
# 0  47570  2018-10-17T00:00:00.000Z      None
# 1  47571  2018-10-17T02:30:00.000Z      None
# 2  47572  2018-10-17T23:00:00.000Z      None
# 3  47573  2018-10-17T23:00:00.000Z      None
# 4  47574  2018-10-17T23:00:00.000Z      None
#
#                              awayTeam                            homeTeam  \
# 0   {'id': 85, 'abbreviation': 'PHI'}   {'id': 82, 'abbreviation': 'BOS'}
# 1   {'id': 96, 'abbreviation': 'OKL'}  {'id': 101, 'abbreviation': 'GSW'}
# 2   {'id': 90, 'abbreviation': 'MIL'}   {'id': 93, 'abbreviation': 'CHA'}
# 3   {'id': 84, 'abbreviation': 'BRO'}   {'id': 88, 'abbreviation': 'DET'}
# 4  {'id': 107, 'abbreviation': 'MEM'}   {'id': 87, 'abbreviation': 'IND'}
#
#                                            venue venueAllegiance  \
# 0                {'id': 27, 'name': 'TD Garden'}            HOME
# 1             {'id': 95, 'name': 'Oracle Arena'}            HOME
# 2          {'id': 87, 'name': 'Spectrum Center'}            HOME
# 3    {'id': 145, 'name': 'Little Caesars Arena'}            HOME
# 4  {'id': 81, 'name': 'Bankers Life Fieldhouse'}            HOME
#
#   scheduleStatus originalStartTime delayedOrPostponedReason playedStatus  \
# 0         NORMAL              None                     None    COMPLETED
# 1         NORMAL              None                     None    COMPLETED
# 2         NORMAL              None                     None    COMPLETED
# 3         NORMAL              None                     None    COMPLETED
# 4         NORMAL              None                     None    COMPLETED
#
#   attendance officials broadcasters weather  \
# 0       None        []           []    None
# 1       None        []           []    None
# 2       None        []           []    None
# 3       None        []           []    None
# 4       None        []           []    None
#
#                                                score
# 0  {'currentQuarter': None, 'currentQuarterSecond...
# 1  {'currentQuarter': None, 'currentQuarterSecond...
# 2  {'currentQuarter': None, 'currentQuarterSecond...
# 3  {'currentQuarter': None, 'currentQuarterSecond...
# 4  {'currentQuarter': None, 'currentQuarterSecond...

# %%
nbaDataScore = pd.concat([nbaData.score.apply(pd.Series), df.drop('score', axis=1)], axis=1)
nbaDataScore.head()
# Out:
#   currentQuarter currentQuarterSecondsRemaining currentIntermission  \
# 0           None                           None                None
# 1           None                           None                None
# 2           None                           None                None
# 3           None                           None                None
# 4           None                           None                None
#
#    awayScoreTotal  homeScoreTotal  \
# 0              87             105
# 1             100             108
# 2             113             112
# 3             100             103
# 4              83             111
#
#                                             quarters  \
# 0  [{'quarterNumber': 1, 'awayScore': 21, 'homeSc...
# 1  [{'quarterNumber': 1, 'awayScore': 23, 'homeSc...
# 2  [{'quarterNumber': 1, 'awayScore': 36, 'homeSc...
# 3  [{'quarterNumber': 1, 'awayScore': 29, 'homeSc...
# 4  [{'quarterNumber': 1, 'awayScore': 16, 'homeSc...
#
#                                             schedule
# 0  {'id': 47570, 'startTime': '2018-10-17T00:00:0...
# 1  {'id': 47571, 'startTime': '2018-10-17T02:30:0...
# 2  {'id': 47572, 'startTime': '2018-10-17T23:00:0...
# 3  {'id': 47573, 'startTime': '2018-10-17T23:00:0...
# 4  {'id': 47574, 'startTime': '2018-10-17T23:00:0...

# %%
nbaData_road = pd.concat([nbaDataSchedule.awayTeam.apply(pd.Series)], axis=1)
nbaData_road.head(10)
# Out:
#     id abbreviation
# 0   85          PHI
# 1   96          OKL
# 2   90          MIL
# 3   84          BRO
# 4  107          MEM
# 5   92          MIA
# 6   91          ATL
# 7   86          CLE
# 8  110          NOP
# 9  100          MIN

# %%
nbaData_home = pd.concat([nbaDataSchedule.homeTeam.apply(pd.Series)], axis=1)
nbaData_home.head(10)
# Out:
#     id abbreviation
# 0   82          BOS
# 1  101          GSW
# 2   93          CHA
# 3   88          DET
# 4   87          IND
# 5   95          ORL
# 6   83          NYK
# 7   81          TOR
# 8  109          HOU
# 9  106          SAS

# %%
nbaData_venue = pd.concat([nbaDataSchedule.venue.apply(pd.Series)], axis=1)
nbaData_venue.head(10)
# Out:
#     id                     name
# 0   27                TD Garden
# 1   95             Oracle Arena
# 2   87          Spectrum Center
# 3  145     Little Caesars Arena
# 4   81  Bankers Life Fieldhouse
# 5   89             Amway Center
# 6   12    Madison Square Garden
# 7    1         Scotiabank Arena
# 8  102            Toyota Center
# 9   99              AT&T Center

# %%
nbaRoadAbr = nbaData_road['abbreviation']
nbaHomeAbr = nbaData_home['abbreviation']
nbaVen = nbaData_venue['name']
nbascoresRoad = nbaDataScore['awayScoreTotal']
nbascoresHome = nbaDataScore['homeScoreTotal']


filteredNBAdata = pd.DataFrame({"Home Team":nbaHomeAbr,
                                "- Score":nbascoresHome,
                                "Road Team":nbaRoadAbr,
                                " - Score":nbascoresRoad,
                                "Venue":nbaVen,})

# %%
filteredNBAdata
# Out:
#      Home Team  - Score Road Team   - Score                    Venue
# 0          BOS      105       PHI        87                TD Garden
# 1          GSW      108       OKL       100             Oracle Arena
# 2          CHA      112       MIL       113          Spectrum Center
# 3          DET      103       BRO       100     Little Caesars Arena
# 4          IND      111       MEM        83  Bankers Life Fieldhouse
# ...        ...      ...       ...       ...                      ...
# 1225       MIL      116       OKL       127             Fiserv Forum
# 1226       SAS      105       DAL        94              AT&T Center
# 1227       DEN       99       MIN        95             Pepsi Center
# 1228       LAC      143       UTA       137           Staples Center
# 1229       POR      136       SAC       131              Moda Center
#
# [1230 rows x 5 columns]

# %%
#team_stats = ['teamStatsTotals']
team_data = []
stats_data = []

lastUpdate = ['lastUpdatedOn']
references = ['references']
#chedule = ['schedule']
for team in team_stats:
    response = msf.msf_get_data(league='nba',season='2018-2019-regular',feed='seasonal_games',format='json')
    lastUpdate.append(response['lastUpdatedOn'])
    references.append(response['references'])
    #chedule.append(response['schedule'])
print(response)
# Out:
# {'lastUpdatedOn': '2020-06-19T16:45:18.311Z', 'games': [{'schedule': {'id': 47570, 'startTime': '2018-10-17T00:00:00.000Z', 'endedTime': None, 'awayTeam': {'id': 85, 'abbreviation': 'PHI'}, 'homeTeam': {'id': 82, 'abbreviation': 'BOS'}, 'venue': {'id': 27, 'name': 'TD Garden'}, 'venueAllegiance': 'HOME', 'scheduleStatus': 'NORMAL', 'originalStartTime': None, 'delayedOrPostponedReason': None, 'playedStatus': 'COMPLETED', 'attendance': None, 'officials': [], 'broadcasters': [], 'weather': None}, 'score': {'currentQuarter': None, 'currentQuarterSecondsRemaining': None, 'currentIntermission': None, 'awayScoreTotal': 87, 'homeScoreTotal': 105, 'quarters': [{'quarterNumber': 1, 'awayScore': 21, 'homeScore': 21}, {'quarterNumber': 2, 'awayScore': 21, 'homeScore': 26}, {'quarterNumber': 3, 'awayScore': 24, 'homeScore': 30}, {'quarterNumber': 4, 'awayScore': 21, 'homeScore': 28}]}}, {'schedule': {'id': 47571, 'startTime': '2018-10-17T02:30:00.000Z', 'endedTime': None, 'awayTeam': {'id': 96, 'abbreviation': 'OKL'}, 'homeTeam': {'id': 101, 'abbreviation': 'GSW'}, 'venue': {'id': 95, 'name': 'Oracle Arena'}, 'venueAllegiance': 'HOME', 'scheduleStatus': 'NORMAL', 'originalStartTime': None, 'delayedOrPostponedReason': None, 'playedStatus': 'COMPLETED', 'attendance': None, 'officials': [], 'broadcasters': [], 'weather': None}, 'score': {'currentQuarter': None, 'currentQuarterSecondsRemaining': None, 'currentIntermission': None, 'awayScoreTotal': 100, 'homeScoreTotal': 108, 'quarters': [{'quarterNumber': 1, 'awayScore': 23, 'homeScore': 31}, {'quarterNumber': 2, 'awayScore': 24, 'homeScore': 26}, {'quarterNumber': 3, 'awayScore': 32, 'homeScore': 26}, {'quarterNumber': 4, 'awayScore': 21, 'homeScore': 25}]}}, {'schedule': {'id': 47572, 'startTime': '2018-10-17T23:00:00.000Z', 'endedTime': None, 'awayTeam': {'id': 90, 'abbreviation': 'MIL'}, 'homeTeam': {'id': 93, 'abbreviation': 'CHA'}, 'venue': {'id': 87, 'name': 'Spectrum Center'}, 'venueAllegiance': 'HOME', 'scheduleStatus': 'NORMAL', 'originalStartTime': None, 'delayedOrPostponedReason': None, 'playedStatus': 'COMPLETED', 'attendance': None, 'officials': [], 'broadcasters': [], 'weather': None}, 'score': {'currentQuarter': None, 'currentQuarterSecondsRemaining': None, 'currentIntermission': None, 'awayScoreTotal': 113, 'homeScoreTotal': 112, 'quarters': [{'quarterNumber': 1, 'awayScore': 36, 'homeScore': 23}, {'quarterNumber': 2, 'awayScore': 31, 'homeScore': 31}, {'quarterNumber': 3, 'awayScore': 26, 'homeScore': 29}, {'quarterNumber': 4, 'awayScore': 20, 'homeScore': 29}]}}, {'schedule': {'id': 47573, 'startTime': '2018-10-17T23:00:00.000Z', 'endedTime': None, 'awayTeam': {'id': 84, 'abbreviation': 'BRO'}, 'homeTeam': {'id': 88, 'abbreviation': 'DET'}, 'venue': {'id': 145, 'name': 'Little Caesars Arena'}, 'venueAllegiance': 'HOME', 'scheduleStatus': 'NORMAL', 'originalStartTime': None, 'delayedOrPostponedReason': None, 'playedStatus': 'COMPLETED', 'attendance': None, 'officials': [], 'broadcasters': [], 'weather': None}, 'score': {'currentQuarter': None, 'currentQuarterSecondsRemaining': None, 'currentIntermission': None, 'awayScoreTotal': 100, 'homeScoreTotal': 103, 'quarters': [{'quarterNumber': 1, 'awayScore': 29, 'homeScore': 24}, {'quarterNumber': 2, 'awayScore': 22, 'homeScore': 27}, {'quarterNumber': 3, 'awayScore': 25, 'homeScore': 32}, {'quarterNumber': 4, 'awayScore': 24, 'homeScore': 20}]}}, {'schedule': {'id': 47574, 'startTime': '2018-10-17T23:00:00.000Z', 'endedTime': None, 'awayTeam': {'id': 107, 'abbreviation': 'MEM'}, 'homeTeam': {'id': 87, 'abbreviation': 'IND'}, 'venue': {'id': 81, 'name': 'Bankers Life Fieldhouse'}, 'venueAllegiance': 'HOME', 'scheduleStatus': 'NORMAL', 'originalStartTime': None, 'delayedOrPostponedReason': None, 'playedStatus': 'COMPLETED', 'attendance': None, 'officials': [], 'broadcasters': [], 'weather': None}, 'score': {'currentQuarter': None, 'currentQuarterSecondsRemaining': None, 'currentIntermission': None, 'awayScoreTotal': 83, 'homeScoreTo ...

# %%
references
# Out:
# ['references',
#  {'teamReferences': [{'id': 81,
#     'city': 'Toronto',
#     'name': 'Raptors',
#     'abbreviation': 'TOR',
#     'homeVenue': {'id': 1, 'name': 'Scotiabank Arena'},
#     'teamColoursHex': ['#ce1141', '#000000', '#a1a1a4', '#b4975a'],
#     'socialMediaAccounts': [{'mediaType': 'TWITTER', 'value': 'Raptors'}],
#     'officialLogoImageSrc': 'https://global.nba.com/media/img/teams/00/logos/TOR_logo.svg'},
#    {'id': 82,
#     'city': 'Boston',
#     'name': 'Celtics',
#     'abbreviation': 'BOS',
#     'homeVenue': {'id': 27, 'name': 'TD Garden'},
#     'teamColoursHex': ['#007a33', '#ba9653', '#963821', '#e59e6d', '#000000'],
#     'socialMediaAccounts': [{'mediaType': 'TWITTER', 'value': 'celtics'}],
#     'officialLogoImageSrc': 'https://global.nba.com/media/img/teams/00/logos/BOS_logo.svg'},
#    {'id': 83,
#     'city': 'New York',
#     'name': 'Knicks',
#     'abbreviation': 'NYK',
#     'homeVenue': {'id': 12, 'name': 'Madison Square Garden'},
#     'teamColoursHex': ['#006bb6', '#f58426', '#bec0c2', '#000000'],
#     'socialMediaAccounts': [{'mediaType': 'TWITTER', 'value': 'nyknicks'}],
#     'officialLogoImageSrc': 'https://global.nba.com/media/img/teams/00/logos/NYK_logo.svg'},
#    {'id': 84,
#     'city': 'Brooklyn',
#     'name': 'Nets',
#     'abbreviation': 'BRO',
#     'homeVenue': {'id': 78, 'name': 'Barclays Center'},
#     'teamColoursHex': ['#000000', '#ffffff'],
#     'socialMediaAccounts': [{'mediaType': 'TWITTER', 'value': 'BrooklynNets'}],
#     'officialLogoImageSrc': 'https://global.nba.com/media/img/teams/00/logos/BKN_logo.svg'},
#    {'id': 85,
#     'city': 'Philadelphia',
#     'name': '76ers',
#     'abbreviation': 'PHI',
#     'homeVenue': {'id': 29, 'name': 'Wells Fargo Center'},
#     'teamColoursHex': ['#006bb6', '#ed174c', '#002b5c', '#c4ced4'],
#     'socialMediaAccounts': [{'mediaType': 'TWITTER', 'value': 'sixers'}],
#     'officialLogoImageSrc': 'https://global.nba.com/media/img/teams/00/logos/PHI_logo.svg'},
#    {'id': 86,
#     'city': 'Cleveland',
#     'name': 'Cavaliers',
#     'abbreviation': 'CLE',
#     'homeVenue': {'id': 80, 'name': 'Quicken Loans Arena'},
#     'teamColoursHex': ['#6f263d', '#041e42', '#ffb81c', '#000000'],
#     'socialMediaAccounts': [{'mediaType': 'TWITTER', 'value': 'cavs'}],
#     'officialLogoImageSrc': 'https://global.nba.com/media/img/teams/00/logos/CLE_logo.svg'},
#    {'id': 87,
#     'city': 'Indiana',
#     'name': 'Pacers',
#     'abbreviation': 'IND',
#     'homeVenue': {'id': 81, 'name': 'Bankers Life Fieldhouse'},
#     'teamColoursHex': ['#002d62', '#fdbb30', '#bec0c2'],
#     'socialMediaAccounts': [{'mediaType': 'TWITTER', 'value': 'Pacers'}],
#     'officialLogoImageSrc': 'https://global.nba.com/media/img/teams/00/logos/IND_logo.svg'},
#    {'id': 88,
#     'city': 'Detroit',
#     'name': 'Pistons',
#     'abbreviation': 'DET',
#     'homeVenue': {'id': 145, 'name': 'Little Caesars Arena'},
#     'teamColoursHex': ['#c8102e', '#006bb6', '#bec0c2', '#002d62'],
#     'socialMediaAccounts': [{'mediaType': 'TWITTER',
#       'value': 'DetroitPistons'}],
#     'officialLogoImageSrc': 'https://global.nba.com/media/img/teams/00/logos/DET_logo.svg'},
#    {'id': 89,
#     'city': 'Chicago',
#     'name': 'Bulls',
#     'abbreviation': 'CHI',
#     'homeVenue': {'id': 28, 'name': 'United Center'},
#     'teamColoursHex': ['#ce1141', '#000000'],
#     'socialMediaAccounts': [{'mediaType': 'TWITTER', 'value': 'chicagobulls'}],
#     'officialLogoImageSrc': 'https://global.nba.com/media/img/teams/00/logos/CHI_logo.svg'},
#    {'id': 90,
#     'city': 'Milwaukee',
#     'name': 'Bucks',
#     'abbreviation': 'MIL',
#     'homeVenue': {'id': 152, 'name': 'Fiserv Forum'},
#     'teamColoursHex': ['#00471b', '#eee1c6', '#0077c0', '#000000'],
#     'socialMediaAccounts': [{'mediaType': 'TWITTER', 'value': 'Bucks'}],
#     'officialLogoImageSrc': 'https://global.nba.com/media/img/teams/00/logos/MIL_logo.svg'},
#    {'id': 91,
#     'city': 'Atlanta',
#     'name': 'Hawks',
#     'abbreviation': 'ATL',
#     'homeVenue': {'id': 20, 'name': 'State Farm Arena'},
#     'teamColoursHex': ['#e03a3e', '#c1d32f', '#26282a'],
#     'socialMediaAccounts': [{'mediaType': 'TWITTER', 'value': 'ATLHawks'}],
#     'officialLogoImageSrc': 'https://global.nba.com/media/img/teams/00/logos/ATL_logo.svg'},
#    {'id': 92,
#     'city': 'Miami',
#     'name': 'Heat',
#     'abbreviation': 'MIA',
#     'homeVenue': {'id': 86, 'name': 'American Airlines Arena'},
#     'teamColoursHex': ['#98002e', '#f9a01b', '#000000'],
#     'socialMediaAccounts': [{'mediaType': 'TWITTER', 'value': 'MiamiHEAT'}],
#     'officialLogoImageSrc': 'https://global.nba.com/media/img/teams/00/logos/MIA_logo.svg'},
#    {'id': 93,
#     'city': 'Charlotte',
#     'name': 'Hornets',
#     'abbreviation': 'CHA',
#     'homeVenue': {'id': 87, 'name': 'Spectrum Center'},
#     'teamColoursHex': ['#1d1160', '#00788c', '#a1a1a4'],
#     'socialMediaAccounts': [{'mediaType': 'TWITTER', 'value': 'hornets'}],
#     'officialLogoImageSrc': 'https://global.nba.com/media/img/teams/00/logos/CHA_logo.svg'},
#    {'id': 94,
#     'city': 'Washington',
#     'name': 'Wizards',
#     'abbreviation': 'WAS',
#     'homeVenue': {'id': 13, 'name': 'Capital One Arena'},
#     'teamColoursHex': ['#002b5c', '#e31837', '#c4ced4'],
#     'socialMediaAccounts': [{'mediaType': 'TWITTER', 'value': 'WashWizards'}],
#     'officialLogoImageSrc': 'https://global.nba.com/media/img/teams/00/logos/WAS_logo.svg'},
#    {'id': 95,
#     'city': 'Orlando',
#     'name': 'Magic',
#     'abbreviation': 'ORL',
#     'homeVenue': {'id': 89, 'name': 'Amway Center'},
#     'teamColoursHex': ['#0077c0', '#c4ced4', '#000000'],
#     'socialMediaAccounts': [{'mediaType': 'TWITTER', 'value': 'OrlandoMagic'}],
#     'officialLogoImageSrc': 'https://global.nba.com/media/img/teams/00/logos/ORL_logo.svg'},
#    {'id': 96,
#     'city': 'Oklahoma City',
#     'name': 'Thunder',
#     'abbreviation': 'OKL',
#     'homeVenue': {'id': 90, 'name': 'Chesapeake Energy Arena'},
#     'teamColoursHex': ['#007ac1', '#ef3b24', '#002d62', '#fdbb30'],
#     'socialMediaAccounts': [{'mediaType': 'TWITTER', 'value': 'okcthunder'}],
#     'officialLogoImageSrc': 'https://global.nba.com/media/img/teams/00/logos/OKC_logo.svg'},
#    {'id': 97,
#     'city': 'Portland',
#     'name': 'Trail Blazers',
#     'abbreviation': 'POR',
#     'homeVenue': {'id': 91, 'name': 'Moda Center'},
#     'teamColoursHex': ['#e03a3e', '#000000'],
#     'socialMediaAccounts': [{'mediaType': 'TWITTER', 'value': 'trailblazers'}],
#     'officialLogoImageSrc': 'https://global.nba.com/media/img/teams/00/logos/POR_logo.svg'},
#    {'id': 98,
#     'city': 'Utah',
#     'name': 'Jazz',
#     'abbreviation': 'UTA',
#     'homeVenue': {'id': 92, 'name': 'Vivint Smart Home Arena'},
#     'teamColoursHex': ['#002b5c', '#00471b', '#f9a01b'],
#     'socialMediaAccounts': [{'mediaType': 'TWITTER', 'value': 'utahjazz'}],
#     'officialLogoImageSrc': 'https://global.nba.com/media/img/teams/00/logos/UTA_logo.svg'},
#    {'id': 99,
#     'city': 'Denver',
#     'name': 'Nuggets',
#     'abbreviation': 'DEN',
#     'homeVenue': {'id': 19, 'name': 'Pepsi Center'},
#     'teamColoursHex': ['#0e2240', '#fec524', '#8b2131', '#1d428a'],
#     'socialMediaAccounts': [{'mediaType': 'TWITTER', 'value': 'nuggets'}],
#     'officialLogoImageSrc': 'https://global.nba.com/media/img/teams/00/logos/DEN_logo.svg'},
#    {'id': 100,
#     'city': 'Minnesota',
#     'name': 'Timberwolves',
#     'abbreviation': 'MIN',
#     'homeVenue': {'id': 94, 'name': 'Target Center'},
#     'teamColoursHex': ['#0c2340', '#236192', '#9ea2a2', '#78be20'],
#     'socialMediaAccounts': [{'mediaType': 'TWITTER', 'value': 'Timberwolves'}],
#     'officialLogoImageSrc': 'https://global.nba.com/media/img/teams/00/logos/MIN_logo.svg'},
#    {'id': 101,
#     'city': 'Golden State',
#     'name': 'Warriors',
#     'abbreviation': 'GSW',
#     'homeVenue': {'id': 95, 'name': 'Oracle Arena'},
#     'teamColoursHex': ['#006bb6', '#fdb927', '#26282a'],
#     'socialMediaAccounts': [{'mediaType': 'TWITTER', 'value': 'warriors'}],
#     'officialLogoImageSrc': 'https://global.nba.com/media/img/teams/00/logos/GSW_logo.svg'},
#    {'id': 102,
#     'city': 'Los Angeles',
#     'name': 'Clippers',
#     'abbreviation': 'LAC',
#     'homeVenue': {'id': 25, 'name': 'Staples Center'},
#     'teamColoursHex': ['#c8102e', '#1d428a', '#bec0c2', '#000000'],
#     'socialMediaAccounts': [{'mediaType': 'TWITTER', 'value': 'LAClippers'}],
#     'officialLogoImageSrc': 'https://global.nba.com/media/img/teams/00/logos/LAC_logo.svg'},
#    {'id': 103,
#     'city': 'Sacramento',
#     'name': 'Kings',
#     'abbreviation': 'SAC',
#     'homeVenue': {'id': 151, 'name': 'Golden 1 Center'},
#     'teamColoursHex': ['#5a2d81', '#63727a', '#000000'],
#     'socialMediaAccounts': [{'mediaType': 'TWITTER',
#       'value': 'SacramentoKings'}],
#     'officialLogoImageSrc': 'https://global.nba.com/media/img/teams/00/logos/SAC_logo.svg'},
#    {'id': 104,
#     'city': 'Phoenix',
#     'name': 'Suns',
#     'abbreviation': 'PHX',
#     'homeVenue': {'id': 98, 'name': 'Talking Stick Resort Arena'},
#     'teamColoursHex': ['#1d1160',
#      '#e56020',
#      '#000000',
#      '#63727a',
#      '#f9ad1b',
#      '#b95915',
#      '#bec0c2'],
#     'socialMediaAccounts': [{'mediaType': 'TWITTER', 'value': 'Suns'}],
#     'officialLogoImageSrc': 'https://global.nba.com/media/img/teams/00/logos/PHX_logo.svg'},
#    {'id': 105,
#     'city': 'Los Angeles',
#     'name': 'Lakers',
#     'abbreviation': 'LAL',
#     'homeVenue': {'id': 25, 'name': 'Staples Center'},
#     'teamColoursHex': ['#552583', '#fdb927', '#000000'],
#     'socialMediaAccounts': [{'mediaType': 'TWITTER', 'value': 'Lakers'}],
#     'officialLogoImageSrc': 'https://global.nba.com/media/img/teams/00/logos/LAL_logo.svg'},
#    {'id': 106,
#     'city': 'San Antonio',
#     'name': 'Spurs',
#     'abbreviation': 'SAS',
#     'homeVenue': {'id': 99, 'name': 'AT&T Center'},
#     'teamColoursHex': ['#c4ced4', '#000000'],
#     'socialMediaAccounts': [{'mediaType': 'TWITTER', 'value': 'spurs'}],
#     'officialLogoImageSrc': 'https://global.nba.com/media/img/teams/00/logos/SAS_logo.svg'},
#    {'id': 107,
#     'city': 'Memphis',
#     'name': 'Grizzlies',
#     'abbreviation': 'MEM',
#     'homeVenue': {'id': 100, 'name': 'FedEx Forum'},
#     'teamColoursHex': ['#5d76a9', '#12173f', '#f5b112', '#707271'],
#     'socialMediaAccounts': [{'mediaType': 'TWITTER', 'value': 'memgrizz'}],
#     'officialLogoImageSrc': 'https://global.nba.com/media/img/teams/00/logos/MEM_logo.svg'},
#    {'id': 108,
#     'city': 'Dallas',
#     'name': 'Mavericks',
#     'abbreviation': 'DAL',
#     'homeVenue': {'id': 2, 'name': 'American Airlines Center'},
#     'teamColoursHex': ['#00538c', '#002b5e', '#b8c4ca', '#000000'],
#     'socialMediaAccounts': [{'mediaType': 'TWITTER', 'value': 'dallasmavs'}],
#     'officialLogoImageSrc': 'https://global.nba.com/media/img/teams/00/logos/DAL_logo.svg'},
#    {'id': 109,
#     'city': 'Houston',
#     'name': 'Rockets',
#     'abbreviation': 'HOU',
#     'homeVenue': {'id': 102, 'name': 'Toyota Center'},
#     'teamColoursHex': ['#ce1141', '#000000', '#c4ced4'],
#     'socialMediaAccounts': [{'mediaType': 'TWITTER',
#       'value': 'HoustonRockets'}],
#     'officialLogoImageSrc': 'https://global.nba.com/media/img/teams/00/logos/HOU_logo.svg'},
#    {'id': 110,
#     'city': 'New Orleans',
#     'name': 'Pelicans',
#     'abbreviation': 'NOP',
#     'homeVenue': {'id': 103, 'name': 'Smoothie King Center'},
#     'teamColoursHex': ['#0c2340', '#c8102e', '#857a4d'],
#     'socialMediaAccounts': [{'mediaType': 'TWITTER', 'value': 'PelicansNBA'}],
#     'officialLogoImageSrc': 'https://global.nba.com/media/img/teams/00/logos/NOP_logo.svg'}],
#   'venueReferences': [{'id': 1,
#     'name': 'Scotiabank Arena',
#     'city': 'Toronto, ON',
#     'country': 'Canada',
#     'geoCoordinates': {'latitude': 43.643333, 'longitude': -79.379167},
#     'capacitiesByEventType': [{'eventType': 'ICE_HOCKEY', 'capacity': 20270},
#      {'eventType': 'BASKETBALL', 'capacity': 20511},
#      {'eventType': 'THEATER', 'capacity': 5200},
#      {'eventType': 'LACROSSE', 'capacity': 18800},
#      {'eventType': 'CONCERT', 'capacity': 19800}],
#     'playingSurface': None,
#     'baseballDimensions': [],
#     'hasRoof': True,
#     'hasRetractableRoof': False},
#    {'id': 2,
#     'name': 'American Airlines Center',
#     'city': 'Dallas, TX',
#     'country': 'USA',
#     'geoCoordinates': {'latitude': 32.790556, 'longitude': -96.810278},
#     'capacitiesByEventType': [{'eventType': 'ICE_HOCKEY', 'capacity': 19323},
#      {'eventType': 'BASKETBALL', 'capacity': 21146},
#      {'eventType': 'CONCERT', 'capacity': 21000}],
#     'playingSurface': 'Multiple',
#     'baseballDimensions': [],
#     'hasRoof': True,
#     'hasRetractableRoof': False},
#    {'id': 12,
#     'name': 'Madison Square Garden',
#     'city': 'New York, NY',
#     'country': 'USA',
#     'geoCoordinates': {'latitude': 40.750556, 'longitude': -73.993611},
#     'capacitiesByEventType': [{'eventType': 'ICE_HOCKEY', 'capacity': 18006},
#      {'eventType': 'BASKETBALL', 'capacity': 19812},
#      {'eventType': 'THEATER', 'capacity': 5600},
#      {'eventType': 'BOXING', 'capacity': 20789},
#      {'eventType': 'WRESTLING', 'capacity': 18500},
#      {'eventType': 'CONCERT', 'capacity': 20000}],
#     'playingSurface': None,
#     'baseballDimensions': [],
#     'hasRoof': True,
#     'hasRetractableRoof': False},
#    {'id': 13,
#     'name': 'Capital One Arena',
#     'city': 'Washington, DC',
#     'country': 'USA',
#     'geoCoordinates': {'latitude': 38.89801, 'longitude': -77.0231909},
#     'capacitiesByEventType': [{'eventType': 'ICE_HOCKEY', 'capacity': 18506},
#      {'eventType': 'BASKETBALL', 'capacity': 20356}],
#     'playingSurface': 'Multiple',
#     'baseballDimensions': [],
#     'hasRoof': True,
#     'hasRetractableRoof': False},
#    {'id': 19,
#     'name': 'Pepsi Center',
#     'city': 'Denver, CO',
#     'country': 'USA',
#     'geoCoordinates': {'latitude': 39.748611, 'longitude': -105.0075},
#     'capacitiesByEventType': [{'eventType': 'ICE_HOCKEY', 'capacity': 17809},
#      {'eventType': 'BASKETBALL', 'capacity': 19520},
#      {'eventType': 'ARENA_FOOTBALL', 'capacity': 17417},
#      {'eventType': 'LACROSSE', 'capacity': 17809},
#      {'eventType': 'CONCERT', 'capacity': 20000}],
#     'playingSurface': 'Multiple',
#     'baseballDimensions': [],
#     'hasRoof': True,
#     'hasRetractableRoof': False},
#    {'id': 20,
#     'name': 'State Farm Arena',
#     'city': 'Atlanta, GA',
#     'country': 'USA',
#     'geoCoordinates': {'latitude': 33.757222, 'longitude': -84.396389},
#     'capacitiesByEventType': [{'eventType': 'ICE_HOCKEY', 'capacity': 17624},
#      {'eventType': 'BASKETBALL', 'capacity': 16600},
#      {'eventType': 'CONCERT', 'capacity': 21000}],
#     'playingSurface': None,
#     'baseballDimensions': [],
#     'hasRoof': True,
#     'hasRetractableRoof': False},
#    {'id': 25,
#     'name': 'Staples Center',
#     'city': 'Los Angeles, CA',
#     'country': 'USA',
#     'geoCoordinates': {'latitude': 34.043056, 'longitude': -118.267222},
#     'capacitiesByEventType': [{'eventType': 'ICE_HOCKEY', 'capacity': 18230},
#      {'eventType': 'BASKETBALL', 'capacity': 19060},
#      {'eventType': 'BOXING', 'capacity': 21000},
#      {'eventType': 'ARENA_FOOTBALL', 'capacity': 16096},
#      {'eventType': 'THEATER', 'capacity': 8000},
#      {'eventType': 'CONCERT', 'capacity': 13000},
#      {'eventType': 'WRESTLING', 'capacity': 21000}],
#     'playingSurface': None,
#     'baseballDimensions': [],
#     'hasRoof': True,
#     'hasRetractableRoof': False},
#    {'id': 27,
#     'name': 'TD Garden',
#     'city': 'Boston, MA',
#     'country': 'USA',
#     'geoCoordinates': {'latitude': 42.366303, 'longitude': -71.062228},
#     'capacitiesByEventType': [{'eventType': 'ICE_HOCKEY', 'capacity': 17565},
#      {'eventType': 'LACROSSE', 'capacity': 17565},
#      {'eventType': 'BASKETBALL', 'capacity': 18624},
#      {'eventType': 'CONCERT', 'capacity': 19580}],
#     'playingSurface': None,
#     'baseballDimensions': [],
#     'hasRoof': True,
#     'hasRetractableRoof': False},
#    {'id': 28,
#     'name': 'United Center',
#     'city': 'Chicago, IL',
#     'country': 'USA',
#     'geoCoordinates': {'latitude': 41.880556, 'longitude': -87.674167},
#     'capacitiesByEventType': [{'eventType': 'ICE_HOCKEY', 'capacity': 22428},
#      {'eventType': 'BASKETBALL', 'capacity': 23129},
#      {'eventType': 'CONCERT', 'capacity': 23500}],
#     'playingSurface': None,
#     'baseballDimensions': [],
#     'hasRoof': True,
#     'hasRetractableRoof': False},
#    {'id': 29,
#     'name': 'Wells Fargo Center',
#     'city': 'Philadelphia, PA',
#     'country': 'USA',
#     'geoCoordinates': {'latitude': 39.901111, 'longitude': -75.171944},
#     'capacitiesByEventType': [{'eventType': 'ICE_HOCKEY', 'capacity': 19306},
#      {'eventType': 'BASKETBALL', 'capacity': 20478},
#      {'eventType': 'ARENA_FOOTBALL', 'capacity': 17597}],
#     'playingSurface': None,
#     'baseballDimensions': [],
#     'hasRoof': True,
#     'hasRetractableRoof': False},
#    {'id': 78,
#     'name': 'Barclays Center',
#     'city': 'Brooklyn, NY',
#     'country': 'USA',
#     'geoCoordinates': {'latitude': 40.682661, 'longitude': -73.975225},
#     'capacitiesByEventType': [{'eventType': 'ICE_HOCKEY', 'capacity': 15795},
#      {'eventType': 'BASKETBALL', 'capacity': 17732},
#      {'eventType': 'BOXING', 'capacity': 16000},
#      {'eventType': 'MMA', 'capacity': 16000},
#      {'eventType': 'CONCERT', 'capacity': 17000},
#      {'eventType': 'WRESTLING', 'capacity': 16000}],
#     'playingSurface': 'Multiple',
#     'baseballDimensions': [],
#     'hasRoof': True,
#     'hasRetractableRoof': False},
#    {'id': 80,
#     'name': 'Quicken Loans Arena',
#     'city': 'Cleveland, OH',
#     'country': 'USA',
#     'geoCoordinates': {'latitude': 41.496389, 'longitude': -81.688056},
#     'capacitiesByEventType': [{'eventType': 'ICE_HOCKEY', 'capacity': 18926},
#      {'eventType': 'BASKETBALL', 'capacity': 19432},
#      {'eventType': 'ARENA_FOOTBALL', 'capacity': 18926}],
#     'playingSurface': None,
#     'baseballDimensions': [],
#     'hasRoof': True,
#     'hasRetractableRoof': False},
#    {'id': 81,
#     'name': 'Bankers Life Fieldhouse',
#     'city': 'Indianapolis, IN',
#     'country': 'USA',
#     'geoCoordinates': {'latitude': 39.763889, 'longitude': -86.155556},
#     'capacitiesByEventType': [{'eventType': 'ICE_HOCKEY', 'capacity': 12300},
#      {'eventType': 'BASKETBALL', 'capacity': 17923},
#      {'eventType': 'CONCERT', 'capacity': 19000}],
#     'playingSurface': 'Multiple',
#     'baseballDimensions': [],
#     'hasRoof': True,
#     'hasRetractableRoof': False},
#    {'id': 86,
#     'name': 'American Airlines Arena',
#     'city': 'Miami, FL',
#     'country': 'USA',
#     'geoCoordinates': {'latitude': 25.781389, 'longitude': -80.188056},
#     'capacitiesByEventType': [{'eventType': 'BASKETBALL', 'capacity': 19600},
#      {'eventType': 'CONCERT', 'capacity': 20021}],
#     'playingSurface': 'Multiple',
#     'baseballDimensions': [],
#     'hasRoof': True,
#     'hasRetractableRoof': False},
#    {'id': 87,
#     'name': 'Spectrum Center',
#     'city': 'Charlotte, NC',
#     'country': 'USA',
#     'geoCoordinates': {'latitude': 35.225, 'longitude': -80.839167},
#     'capacitiesByEventType': [{'eventType': 'BASKETBALL', 'capacity': 20200},
#      {'eventType': 'THEATER', 'capacity': 7000},
#      {'eventType': 'WRESTLING', 'capacity': 20200},
#      {'eventType': 'CONCERT', 'capacity': 18504}],
#     'playingSurface': 'Multiple',
#     'baseballDimensions': [],
#     'hasRoof': True,
#     'hasRetractableRoof': False},
#    {'id': 89,
#     'name': 'Amway Center',
#     'city': 'Orlando, FL',
#     'country': 'USA',
#     'geoCoordinates': {'latitude': 28.539167, 'longitude': -81.383611},
#     'capacitiesByEventType': [{'eventType': 'END_STAGE_CONCERT',
#       'capacity': 16486},
#      {'eventType': 'ICE_HOCKEY', 'capacity': 17353},
#      {'eventType': 'NCAA_BASKETBALL', 'capacity': 20000},
#      {'eventType': 'ARENA_FOOTBALL', 'capacity': 17192},
#      {'eventType': 'NBA', 'capacity': 18846},
#      {'eventType': 'CENTER_STAGE_CONCERT', 'capacity': 17030}],
#     'playingSurface': 'Multiple',
#     'baseballDimensions': [],
#     'hasRoof': True,
#     'hasRetractableRoof': False},
#    {'id': 90,
#     'name': 'Chesapeake Energy Arena',
#     'city': 'Oklahama City, OK',
#     'country': 'USA',
#     'geoCoordinates': {'latitude': 35.463333, 'longitude': -97.515},
#     'capacitiesByEventType': [{'eventType': 'ICE_HOCKEY', 'capacity': 15152},
#      {'eventType': 'BASKETBALL', 'capacity': 18203},
#      {'eventType': 'BOXING', 'capacity': 16757},
#      {'eventType': 'MMA', 'capacity': 16757},
#      {'eventType': 'CONCERT', 'capacity': 16591},
#      {'eventType': 'WRESTLING', 'capacity': 16757}],
#     'playingSurface': None,
#     'baseballDimensions': [],
#     'hasRoof': True,
#     'hasRetractableRoof': False},
#    {'id': 91,
#     'name': 'Moda Center',
#     'city': 'Portland, OR',
#     'country': 'USA',
#     'geoCoordinates': {'latitude': 45.531667, 'longitude': -122.666667},
#     'capacitiesByEventType': [{'eventType': 'ICE_HOCKEY', 'capacity': 18280},
#      {'eventType': 'BASKETBALL', 'capacity': 19393},
#      {'eventType': 'THEATER', 'capacity': 6500},
#      {'eventType': 'LACROSSE', 'capacity': 18280},
#      {'eventType': 'CONCERT', 'capacity': 20500}],
#     'playingSurface': None,
#     'baseballDimensions': [],
#     'hasRoof': True,
#     'hasRetractableRoof': False},
#    {'id': 92,
#     'name': 'Vivint Smart Home Arena',
#     'city': 'Salt Lake City, UT',
#     'country': 'USA',
#     'geoCoordinates': {'latitude': 40.768333, 'longitude': -111.901111},
#     'capacitiesByEventType': [{'eventType': 'GENERAL', 'capacity': 18300}],
#     'playingSurface': None,
#     'baseballDimensions': [],
#     'hasRoof': True,
#     'hasRetractableRoof': False},
#    {'id': 94,
#     'name': 'Target Center',
#     'city': 'Minneapolis, MN',
#     'country': 'USA',
#     'geoCoordinates': {'latitude': 44.979444, 'longitude': -93.276111},
#     'capacitiesByEventType': [{'eventType': 'ICE_HOCKEY', 'capacity': 17500},
#      {'eventType': 'BASKETBALL', 'capacity': 18798},
#      {'eventType': 'CONCERT', 'capacity': 20500}],
#     'playingSurface': 'Multiple',
#     'baseballDimensions': [],
#     'hasRoof': True,
#     'hasRetractableRoof': False},
#    {'id': 95,
#     'name': 'Oracle Arena',
#     'city': 'Oakland, CA',
#     'country': 'USA',
#     'geoCoordinates': {'latitude': 37.750278, 'longitude': -122.203056},
#     'capacitiesByEventType': [{'eventType': 'BASKETBALL', 'capacity': 19596}],
#     'playingSurface': None,
#     'baseballDimensions': [],
#     'hasRoof': True,
#     'hasRetractableRoof': False},
#    {'id': 98,
#     'name': 'Talking Stick Resort Arena',
#     'city': 'Phoenix, AZ',
#     'country': 'USA',
#     'geoCoordinates': {'latitude': 33.445833, 'longitude': -112.071389},
#     'capacitiesByEventType': [{'eventType': 'GENERAL', 'capacity': 18422}],
#     'playingSurface': None,
#     'baseballDimensions': [],
#     'hasRoof': True,
#     'hasRetractableRoof': False},
#    {'id': 99,
#     'name': 'AT&T Center',
#     'city': 'San Antonio, TX',
#     'country': 'USA',
#     'geoCoordinates': {'latitude': 29.426944, 'longitude': -98.4375},
#     'capacitiesByEventType': [{'eventType': 'ICE_HOCKEY', 'capacity': 16151},
#      {'eventType': 'BASKETBALL', 'capacity': 18418},
#      {'eventType': 'CONCERT', 'capacity': 19000}],
#     'playingSurface': 'Multiple',
#     'baseballDimensions': [],
#     'hasRoof': True,
#     'hasRetractableRoof': False},
#    {'id': 100,
#     'name': 'FedEx Forum',
#     'city': 'Memphis, TN',
#     'country': 'USA',
#     'geoCoordinates': {'latitude': 35.138333, 'longitude': -90.050556},
#     'capacitiesByEventType': [{'eventType': 'ICE_HOCKEY', 'capacity': 16411},
#      {'eventType': 'BASKETBALL', 'capacity': 18119},
#      {'eventType': 'CONCERT', 'capacity': 19000}],
#     'playingSurface': None,
#     'baseballDimensions': [],
#     'hasRoof': True,
#     'hasRetractableRoof': False},
#    {'id': 102,
#     'name': 'Toyota Center',
#     'city': 'Houston, TX',
#     'country': 'USA',
#     'geoCoordinates': {'latitude': 29.750833, 'longitude': -95.362222},
#     'capacitiesByEventType': [{'eventType': 'BASKETBALL', 'capacity': 18055},
#      {'eventType': 'CONCERT', 'capacity': 19000}],
#     'playingSurface': None,
#     'baseballDimensions': [],
#     'hasRoof': True,
#     'hasRetractableRoof': False},
#    {'id': 103,
#     'name': 'Smoothie King Center',
#     'city': 'New Orleans, LA',
#     'country': 'USA',
#     'geoCoordinates': {'latitude': 29.948889, 'longitude': -90.081944},
#     'capacitiesByEventType': [{'eventType': 'ICE_HOCKEY', 'capacity': 16900},
#      {'eventType': 'BASKETBALL', 'capacity': 18500},
#      {'eventType': 'ARENA_FOOTBALL', 'capacity': 16900},
#      {'eventType': 'CONCERT', 'capacity': 17805}],
#     'playingSurface': None,
#     'baseballDimensions': [],
#     'hasRoof': True,
#     'hasRetractableRoof': False},
#    {'id': 145,
#     'name': 'Little Caesars Arena',
#     'city': 'Detroit, MI',
#     'country': 'USA',
#     'geoCoordinates': {'latitude': 42.341111, 'longitude': -83.055},
#     'capacitiesByEventType': [{'eventType': 'ICE_HOCKEY', 'capacity': 19515},
#      {'eventType': 'BASKETBALL', 'capacity': 20491},
#      {'eventType': 'CONCERT', 'capacity': 22000}],
#     'playingSurface': None,
#     'baseballDimensions': [],
#     'hasRoof': True,
#     'hasRetractableRoof': False},
#    {'id': 151,
#     'name': 'Golden 1 Center',
#     'city': 'Sacramento, CA',
#     'country': 'USA',
#     'geoCoordinates': {'latitude': 38.580361, 'longitude': -121.499611},
#     'capacitiesByEventType': [{'eventType': 'BASKETBALL', 'capacity': 17608},
#      {'eventType': 'CONCERT', 'capacity': 19000}],
#     'playingSurface': None,
#     'baseballDimensions': [],
#     'hasRoof': True,
#     'hasRetractableRoof': False},
#    {'id': 152,
#     'name': 'Fiserv Forum',
#     'city': 'Milwaukee, WI',
#     'country': 'USA',
#     'geoCoordinates': {'latitude': 43.045028, 'longitude': -87.918167},
#     'capacitiesByEventType': [{'eventType': 'GENERAL', 'capacity': 17341}],
#     'playingSurface': None,
#     'baseballDimensions': [],
#     'hasRoof': True,
#     'hasRetractableRoof': False}]}]

# %%
nbaRefDict = references[1]
nbaRefData = pd.DataFrame.from_dict(nbaRefDict, orient='index')
nbaRefData
# Out:
#                                                                 0   \
# teamReferences   {'id': 81, 'city': 'Toronto', 'name': 'Raptors...
# venueReferences  {'id': 1, 'name': 'Scotiabank Arena', 'city': ...
#
#                                                                 1   \
# teamReferences   {'id': 82, 'city': 'Boston', 'name': 'Celtics'...
# venueReferences  {'id': 2, 'name': 'American Airlines Center', ...
#
#                                                                 2   \
# teamReferences   {'id': 83, 'city': 'New York', 'name': 'Knicks...
# venueReferences  {'id': 12, 'name': 'Madison Square Garden', 'c...
#
#                                                                 3   \
# teamReferences   {'id': 84, 'city': 'Brooklyn', 'name': 'Nets',...
# venueReferences  {'id': 13, 'name': 'Capital One Arena', 'city'...
#
#                                                                 4   \
# teamReferences   {'id': 85, 'city': 'Philadelphia', 'name': '76...
# venueReferences  {'id': 19, 'name': 'Pepsi Center', 'city': 'De...
#
#                                                                 5   \
# teamReferences   {'id': 86, 'city': 'Cleveland', 'name': 'Caval...
# venueReferences  {'id': 20, 'name': 'State Farm Arena', 'city':...
#
#                                                                 6   \
# teamReferences   {'id': 87, 'city': 'Indiana', 'name': 'Pacers'...
# venueReferences  {'id': 25, 'name': 'Staples Center', 'city': '...
#
#                                                                 7   \
# teamReferences   {'id': 88, 'city': 'Detroit', 'name': 'Pistons...
# venueReferences  {'id': 27, 'name': 'TD Garden', 'city': 'Bosto...
#
#                                                                 8   \
# teamReferences   {'id': 89, 'city': 'Chicago', 'name': 'Bulls',...
# venueReferences  {'id': 28, 'name': 'United Center', 'city': 'C...
#
#                                                                 9   ...  \
# teamReferences   {'id': 90, 'city': 'Milwaukee', 'name': 'Bucks...  ...
# venueReferences  {'id': 29, 'name': 'Wells Fargo Center', 'city...  ...
#
#                                                                 20  \
# teamReferences   {'id': 101, 'city': 'Golden State', 'name': 'W...
# venueReferences  {'id': 95, 'name': 'Oracle Arena', 'city': 'Oa...
#
#                                                                 21  \
# teamReferences   {'id': 102, 'city': 'Los Angeles', 'name': 'Cl...
# venueReferences  {'id': 98, 'name': 'Talking Stick Resort Arena...
#
#                                                                 22  \
# teamReferences   {'id': 103, 'city': 'Sacramento', 'name': 'Kin...
# venueReferences  {'id': 99, 'name': 'AT&T Center', 'city': 'San...
#
#                                                                 23  \
# teamReferences   {'id': 104, 'city': 'Phoenix', 'name': 'Suns',...
# venueReferences  {'id': 100, 'name': 'FedEx Forum', 'city': 'Me...
#
#                                                                 24  \
# teamReferences   {'id': 105, 'city': 'Los Angeles', 'name': 'La...
# venueReferences  {'id': 102, 'name': 'Toyota Center', 'city': '...
#
#                                                                 25  \
# teamReferences   {'id': 106, 'city': 'San Antonio', 'name': 'Sp...
# venueReferences  {'id': 103, 'name': 'Smoothie King Center', 'c...
#
#                                                                 26  \
# teamReferences   {'id': 107, 'city': 'Memphis', 'name': 'Grizzl...
# venueReferences  {'id': 145, 'name': 'Little Caesars Arena', 'c...
#
#                                                                 27  \
# teamReferences   {'id': 108, 'city': 'Dallas', 'name': 'Maveric...
# venueReferences  {'id': 151, 'name': 'Golden 1 Center', 'city':...
#
#                                                                 28  \
# teamReferences   {'id': 109, 'city': 'Houston', 'name': 'Rocket...
# venueReferences  {'id': 152, 'name': 'Fiserv Forum', 'city': 'M...
#
#                                                                 29
# teamReferences   {'id': 110, 'city': 'New Orleans', 'name': 'Pe...
# venueReferences                                               None
#
# [2 rows x 30 columns]

# %%
nbaRef = nbaRefData.transpose()
nbaRef.head()
# Out:
#                                       teamReferences  \
# 0  {'id': 81, 'city': 'Toronto', 'name': 'Raptors...
# 1  {'id': 82, 'city': 'Boston', 'name': 'Celtics'...
# 2  {'id': 83, 'city': 'New York', 'name': 'Knicks...
# 3  {'id': 84, 'city': 'Brooklyn', 'name': 'Nets',...
# 4  {'id': 85, 'city': 'Philadelphia', 'name': '76...
#
#                                      venueReferences
# 0  {'id': 1, 'name': 'Scotiabank Arena', 'city': ...
# 1  {'id': 2, 'name': 'American Airlines Center', ...
# 2  {'id': 12, 'name': 'Madison Square Garden', 'c...
# 3  {'id': 13, 'name': 'Capital One Arena', 'city'...
# 4  {'id': 19, 'name': 'Pepsi Center', 'city': 'De...

# %%
nbaTeamRef = pd.concat([nbaRef.teamReferences.apply(pd.Series)], axis=1)
nbaTeamRef.head()
# Out:
#    id          city     name abbreviation  \
# 0  81       Toronto  Raptors          TOR
# 1  82        Boston  Celtics          BOS
# 2  83      New York   Knicks          NYK
# 3  84      Brooklyn     Nets          BRO
# 4  85  Philadelphia    76ers          PHI
#
#                                      homeVenue  \
# 0        {'id': 1, 'name': 'Scotiabank Arena'}
# 1              {'id': 27, 'name': 'TD Garden'}
# 2  {'id': 12, 'name': 'Madison Square Garden'}
# 3        {'id': 78, 'name': 'Barclays Center'}
# 4     {'id': 29, 'name': 'Wells Fargo Center'}
#
#                                   teamColoursHex  \
# 0           [#ce1141, #000000, #a1a1a4, #b4975a]
# 1  [#007a33, #ba9653, #963821, #e59e6d, #000000]
# 2           [#006bb6, #f58426, #bec0c2, #000000]
# 3                             [#000000, #ffffff]
# 4           [#006bb6, #ed174c, #002b5c, #c4ced4]
#
#                                  socialMediaAccounts  \
# 0     [{'mediaType': 'TWITTER', 'value': 'Raptors'}]
# 1     [{'mediaType': 'TWITTER', 'value': 'celtics'}]
# 2    [{'mediaType': 'TWITTER', 'value': 'nyknicks'}]
# 3  [{'mediaType': 'TWITTER', 'value': 'BrooklynNe...
# 4      [{'mediaType': 'TWITTER', 'value': 'sixers'}]
#
#                                 officialLogoImageSrc
# 0  https://global.nba.com/media/img/teams/00/logo...
# 1  https://global.nba.com/media/img/teams/00/logo...
# 2  https://global.nba.com/media/img/teams/00/logo...
# 3  https://global.nba.com/media/img/teams/00/logo...
# 4  https://global.nba.com/media/img/teams/00/logo...

# %%
nbaVenRef = pd.concat([nbaRef.venueReferences.apply(pd.Series)], axis=1)
nbaVenRef.head()
# Out:
#      id                      name            city country  \
# 0   1.0          Scotiabank Arena     Toronto, ON  Canada
# 1   2.0  American Airlines Center      Dallas, TX     USA
# 2  12.0     Madison Square Garden    New York, NY     USA
# 3  13.0         Capital One Arena  Washington, DC     USA
# 4  19.0              Pepsi Center      Denver, CO     USA
#
#                                      geoCoordinates  \
# 0  {'latitude': 43.643333, 'longitude': -79.379167}
# 1  {'latitude': 32.790556, 'longitude': -96.810278}
# 2  {'latitude': 40.750556, 'longitude': -73.993611}
# 3  {'latitude': 38.89801, 'longitude': -77.0231909}
# 4   {'latitude': 39.748611, 'longitude': -105.0075}
#
#                                capacitiesByEventType playingSurface  \
# 0  [{'eventType': 'ICE_HOCKEY', 'capacity': 20270...           None
# 1  [{'eventType': 'ICE_HOCKEY', 'capacity': 19323...       Multiple
# 2  [{'eventType': 'ICE_HOCKEY', 'capacity': 18006...           None
# 3  [{'eventType': 'ICE_HOCKEY', 'capacity': 18506...       Multiple
# 4  [{'eventType': 'ICE_HOCKEY', 'capacity': 17809...       Multiple
#
#   baseballDimensions hasRoof hasRetractableRoof
# 0                 []    True              False
# 1                 []    True              False
# 2                 []    True              False
# 3                 []    True              False
# 4                 []    True              False

# %%
nbaGeoRef = pd.concat([nbaVenRef.geoCoordinates.apply(pd.Series)], axis=1)
nbaGeoRef.head()
# Out:
#     latitude   longitude   0
# 0  43.643333  -79.379167 NaN
# 1  32.790556  -96.810278 NaN
# 2  40.750556  -73.993611 NaN
# 3  38.898010  -77.023191 NaN
# 4  39.748611 -105.007500 NaN

# %%
teamName = nbaTeamRef['name']
teamAbr = nbaTeamRef['abbreviation']
teamCity = nbaVenRef['city']
teamArena = nbaVenRef['name']
teamLat = nbaGeoRef['latitude']
teamLng = nbaGeoRef['longitude']

filteredNBAref = pd.DataFrame({"Team Name":teamName,
                                "Abbreviation":teamAbr,
                                "City, State": teamCity,
                                "Venue":teamArena,
                                "Latitude":teamLat,
                               "Longitude":teamLng})

# %%
filteredNBAref
# Out:
#         Team Name Abbreviation         City, State  \
# 0         Raptors          TOR         Toronto, ON
# 1         Celtics          BOS          Dallas, TX
# 2          Knicks          NYK        New York, NY
# 3            Nets          BRO      Washington, DC
# 4           76ers          PHI          Denver, CO
# 5       Cavaliers          CLE         Atlanta, GA
# 6          Pacers          IND     Los Angeles, CA
# 7         Pistons          DET          Boston, MA
# 8           Bulls          CHI         Chicago, IL
# 9           Bucks          MIL    Philadelphia, PA
# 10          Hawks          ATL        Brooklyn, NY
# 11           Heat          MIA       Cleveland, OH
# 12        Hornets          CHA    Indianapolis, IN
# 13        Wizards          WAS           Miami, FL
# 14          Magic          ORL       Charlotte, NC
# 15        Thunder          OKL         Orlando, FL
# 16  Trail Blazers          POR   Oklahama City, OK
# 17           Jazz          UTA        Portland, OR
# 18        Nuggets          DEN  Salt Lake City, UT
# 19   Timberwolves          MIN     Minneapolis, MN
# 20       Warriors          GSW         Oakland, CA
# 21       Clippers          LAC         Phoenix, AZ
# 22          Kings          SAC     San Antonio, TX
# 23           Suns          PHX         Memphis, TN
# 24         Lakers          LAL         Houston, TX
# 25          Spurs          SAS     New Orleans, LA
# 26      Grizzlies          MEM         Detroit, MI
# 27      Mavericks          DAL      Sacramento, CA
# 28        Rockets          HOU       Milwaukee, WI
# 29       Pelicans          NOP                 NaN
#
#                          Venue   Latitude   Longitude
# 0             Scotiabank Arena  43.643333  -79.379167
# 1     American Airlines Center  32.790556  -96.810278
# 2        Madison Square Garden  40.750556  -73.993611
# 3            Capital One Arena  38.898010  -77.023191
# 4                 Pepsi Center  39.748611 -105.007500
# 5             State Farm Arena  33.757222  -84.396389
# 6               Staples Center  34.043056 -118.267222
# 7                    TD Garden  42.366303  -71.062228
# 8                United Center  41.880556  -87.674167
# 9           Wells Fargo Center  39.901111  -75.171944
# 10             Barclays Center  40.682661  -73.975225
# 11         Quicken Loans Arena  41.496389  -81.688056
# 12     Bankers Life Fieldhouse  39.763889  -86.155556
# 13     American Airlines Arena  25.781389  -80.188056
# 14             Spectrum Center  35.225000  -80.839167
# 15                Amway Center  28.539167  -81.383611
# 16     Chesapeake Energy Arena  35.463333  -97.515000
# 17                 Moda Center  45.531667 -122.666667
# 18     Vivint Smart Home Arena  40.768333 -111.901111
# 19               Target Center  44.979444  -93.276111
# 20                Oracle Arena  37.750278 -122.203056
# 21  Talking Stick Resort Arena  33.445833 -112.071389
# 22                 AT&T Center  29.426944  -98.437500
# 23                 FedEx Forum  35.138333  -90.050556
# 24               Toyota Center  29.750833  -95.362222
# 25        Smoothie King Center  29.948889  -90.081944
# 26        Little Caesars Arena  42.341111  -83.055000
# 27             Golden 1 Center  38.580361 -121.499611
# 28                Fiserv Forum  43.045028  -87.918167
# 29                         NaN        NaN         NaN
